# %%
import pandas as pd
import tarfile
import os

# %%
tar = tarfile.open('assets/villes.tar.gz', 'r:gz')
tar.extractall(path=('assets'))
tar.close()

# %%
import random

# %%
from pandas import read_csv

# %%
villes = read_csv('assets/csv/cities.csv', encoding = "ISO-8859-1", usecols=['name'])

# %%
output = "assets/travel_training.csv"

# %%
villes
# Out:
#                            name
# 0      L'Abergement-ClÃ©menciat
# 1         L'Abergement-de-Varey
# 2            AmbÃ©rieu-en-Bugey
# 3          AmbÃ©rieux-en-Dombes
# 4                      AmblÃ©on
# ...                         ...
# 35848                     Touho
# 35849                       Voh
# 35850                     YatÃ©
# 35851                   Kouaoua
# 35852        Ãle de Clipperton
#
# [35853 rows x 1 columns]

# %%
patterns = [
        "Après avoir exploré les rues animées de {}, je me suis dirigé(e) vers {} pour un peu de tranquillité.",
        "De {} à {}, j'ai suivi les traces de l'histoire et de la culture locale.",
        "J'ai sillonné les sentiers verdoyants de {} avant de me retrouver à {} pour une immersion urbaine.",
        "Après avoir goûté aux délices culinaires de {}, j'ai cherché à découvrir les spécialités de {}.",
        "En passant par {}, j'ai été ébloui(e) par la diversité architecturale avant de me rendre à {} pour explorer les traditions locales.",
        "De {} jusqu'à {}, j'ai suivi le cours d'un fleuve et découvert des paysages à couper le souffle.",
        "Après avoir plongé dans l'histoire de {}, j'ai poursuivi mon chemin jusqu'à {} pour des aventures modernes.",
        "J'ai vogué des plages de sable fin de {} vers les sommets majestueux de {}.",
        "Après avoir arpenté les ruelles étroites de {}, j'ai pris la direction de {} pour une vue panoramique.",
        "En partant de {}, j'ai traversé des vallées verdoyantes pour arriver à {} et ses montagnes escarpées.",
        "De {} à {}, j'ai été subjugué(e) par la fusion parfaite entre tradition et modernité.",
        "Après avoir exploré les quartiers animés de {}, je me suis ressourcé(e) dans la quiétude de {}.",
        "J'ai suivi la route des vins de {} à {}, découvrant ainsi les saveurs uniques de chaque région.",
        "En passant par {}, j'ai été émerveillé(e) par l'art avant-gardiste avant de rejoindre {} pour une expérience culturelle différente.",
        "Après avoir découvert les vestiges anciens de {}, j'ai pris le chemin de {} pour une immersion dans la nature.",
        "De {} jusqu'à {}, j'ai exploré les contrastes entre les villes animées et les villages pittoresques.",
        "J'ai suivi le cours d'une rivière de {} à {} en découvrant des paysages variés et enchanteurs.",
        "En partant de {}, j'ai été attiré(e) par la vie nocturne effervescente de {}.",
        "Après avoir visité les musées de {}, j'ai décidé de m'aventurer vers {} pour une expérience artistique différente.",
        "De {} à {}, j'ai parcouru des sentiers insolites pour découvrir des trésors cachés.",
        "J'ai plongé dans les eaux cristallines de {} avant de gravir les sommets de {} pour une vue imprenable.",
        "Après avoir flâné dans les jardins botaniques de {}, j'ai pris la direction de {} pour explorer des parcs nationaux.",
        "En passant par {}, j'ai exploré les marchés locaux avant de me rendre à {} pour une immersion dans la cuisine régionale.",
        "De {} jusqu'à {}, j'ai suivi les chemins de traverse pour découvrir des panoramas spectaculaires.",
        "J'ai suivi la piste des aventuriers de {} à {} en explorant des sentiers hors des sentiers battus.",
        "Après avoir exploré les quartiers colorés de {}, j'ai pris la route vers {} pour une plongée dans la diversité culturelle.",
        "De {} à {}, j'ai suivi les traces des explorateurs anciens tout en explorant des attractions modernes.",
        "En partant de {}, j'ai découvert les richesses cachées de {} à travers des expériences authentiques.",
        "Après avoir admiré les édifices historiques de {}, j'ai continué vers {} pour explorer des sites naturels.",
        "De {} jusqu'à {}, j'ai parcouru des terres fertiles et des déserts arides pour une expérience contrastée.",
        "J'ai suivi la route des artisans de {} à {} pour découvrir l'artisanat local et ses secrets.",
        "En passant par {}, j'ai exploré les quartiers artistiques avant de me rendre à {} pour une immersion spirituelle.",
        "De {} à {}, j'ai été séduit(e) par la diversité des paysages et des traditions locales.",
        "J'ai suivi la trace des explorateurs maritimes de {} à {} pour une aventure océanique.",
        "Après avoir exploré les marchés animés de {}, j'ai suivi la piste vers {} pour une expérience gastronomique inoubliable.",
        "En partant de {}, j'ai suivi le chemin vers {} pour découvrir les merveilles naturelles cachées.",
        "De {} jusqu'à {}, j'ai suivi les sentiers des anciens habitants tout en découvrant des cultures contemporaines.",
        "Après avoir flâné dans les rues animées de {}, j'ai pris la direction de {} pour des expériences de plein air.",
        "J'ai suivi la route des explorateurs culinaires de {} à {} en dégustant des mets locaux authentiques.",
        "En passant par {}, j'ai été séduit(e) par les festivals culturels avant de me rendre à {} pour des escapades rurales.",
        "De {} à {}, j'ai suivi les chemins des conteurs locaux tout en explorant des sites historiques.",
        "J'ai exploré les quartiers cosmopolites de {} avant de rejoindre {} pour une immersion dans la nature sauvage.",
        "Après avoir exploré les rues animées de {}, j'ai savouré la tranquillité de {}.",
        "En quittant {}, je me suis émerveillé(e) devant la majesté de {}.",
        "Mon périple a commencé à {} où j'ai été accueilli(e) chaleureusement avant de me rendre à {}.",
        "J'ai découvert une culture fascinante à {} avant de m'immerger dans celle de {}.",
        "Après avoir contemplé les paysages envoûtants de {}, j'ai pris la route vers {}.",
        "En visitant {}, j'ai été inspiré(e) par l'histoire avant de découvrir les merveilles de {}.",
        "J'ai décidé de faire un détour par {} pour apprécier les délices culinaires avant de continuer vers {}.",
        "De {}, j'ai fait un saut à {} pour une expérience enrichissante avant de revenir à mon itinéraire initial vers {}.",
        "Après avoir rencontré des habitants sympathiques à {}, j'ai poursuivi mon chemin vers {} pour explorer davantage.",
        "Mon voyage a débuté par une escale à {} où j'ai été séduit(e) par la culture locale avant de me diriger vers {}.",
        "En quittant {}, j'ai été captivé(e) par la diversité culturelle de {}.",
        "Après avoir profité des paysages spectaculaires de {}, j'ai repris la route vers {}.",
        "J'ai choisi de m'éloigner de la foule en passant par {} pour découvrir la quiétude de {}.",
        "En explorant {}, j'ai été ébloui(e) par la richesse architecturale avant de me diriger vers {}.",
        "Après avoir découvert les traditions uniques de {}, j'ai continué vers {} pour vivre de nouvelles expériences.",
        "En quittant la modernité de {}, je suis allé(e) à {} pour me plonger dans la nature sauvage.",
        "J'ai été attiré(e) par les festivités animées de {} avant de me rendre à {} pour un contraste apaisant.",
        "Après avoir arpenté les ruelles de {} et exploré ses secrets, j'ai pris la direction de {} pour une atmosphère différente.",
        "En passant par {}, j'ai été subjugué(e) par l'authenticité avant de poursuivre vers {} pour un nouveau chapitre de mon voyage.",
        "J'ai commencé mon aventure à {} en me laissant surprendre par sa diversité avant de partir à la découverte de {}.",
        "Après avoir profité de la convivialité de {}, j'ai repris ma route vers {} pour découvrir de nouvelles perspectives.",
        "En quittant {}, j'ai été fasciné(e) par l'héritage historique avant de m'immerger dans la modernité de {}.",
        "J'ai décidé de faire une halte à {} pour une expérience culturelle unique avant de rejoindre {} pour la suite de mon voyage.",
        "Après avoir exploré les trésors cachés de {}, j'ai décidé de visiter {} pour élargir mes horizons.",
        "En découvrant les coutumes authentiques de {}, j'ai poursuivi mon périple vers {} pour de nouvelles découvertes.",
        "J'ai été séduit(e) par la tranquillité de {} avant de repartir pour {} où l'aventure m'attendait.",
        "Après avoir exploré {}, j'ai fait une pause à {} pour me ressourcer avant de continuer vers {}.",
        "En quittant {}, j'ai été charmé(e) par la simplicité de {} avant de poursuivre vers de nouveaux horizons à {}.",
        "J'ai commencé mon voyage à {} où j'ai été plongé(e) dans une ambiance authentique avant de me rendre à {} pour explorer davantage.",
        "Après avoir découvert les richesses artistiques de {}, j'ai pris la direction de {} pour une immersion différente.",
        "En passant par {}, j'ai été surpris(e) par la diversité culturelle avant de me diriger vers {} pour un tout autre paysage.",
        "J'ai décidé de faire une escale à {} pour me perdre dans ses ruelles avant de reprendre ma route vers {}.",
        "Après avoir savouré l'ambiance vibrante de {}, j'ai pris le chemin de {} pour une atmosphère plus paisible.",
        "En quittant {}, j'ai été ému(e) par la spiritualité avant de me rendre à {} pour une expérience spirituelle différente.",
        "J'ai été inspiré(e) par l'authenticité de {} avant de continuer mon voyage vers {} pour une aventure hors du commun.",
        "Après avoir exploré {}, j'ai choisi de m'évader à {} pour un changement radical d'atmosphère.",
        "En découvrant {}, j'ai été immergé(e) dans la culture locale avant de me rendre à {} pour explorer de nouvelles traditions.",
        "J'ai décidé de faire un détour par {} pour un moment de détente avant de poursuivre vers {} pour de nouvelles découvertes.",
        "Après avoir apprécié la gastronomie de {}, j'ai repris ma route vers {} pour une exploration plus approfondie.",
        "En quittant {}, j'ai été frappé(e) par la diversité culturelle avant de me diriger vers {} pour une immersion différente.",
        "J'ai commencé mon périple à {} où j'ai été charmé(e) par l'authenticité avant de rejoindre {} pour une expérience inoubliable.",
        "Après avoir exploré {}, j'ai fait une halte à {} pour m'imprégner de son histoire avant de poursuivre vers {}.",
        "En passant par {}, j'ai été captivé(e) par la beauté naturelle avant de me rendre à {} pour une aventure inattendue.",
        "Après avoir exploré {}, je me suis dirigé(e) vers {} pour une immersion totale dans une nouvelle culture.",
        "En partant de {}, j'ai suivi un chemin sinueux pour finalement arriver à {} et être ébloui(e) par sa beauté naturelle.",
        "Mon périple m'a conduit(e) de {} à {} où j'ai eu l'occasion de m'immerger dans l'histoire fascinante de ces lieux.",
        "Après une halte à {}, j'ai continué mon voyage jusqu'à {} pour vivre une aventure inattendue.",
        "De {} jusqu'à {}, chaque étape de mon itinéraire a été marquée par des rencontres inspirantes.",
        "En explorant {}, j'ai été séduit(e) par son architecture avant-gardiste avant de me rendre à {} pour une expérience plus traditionnelle.",
        "J'ai quitté {} pour me rendre à {} où j'ai été accueilli(e) chaleureusement par les habitants.",
        "Après avoir découvert {}, j'ai décidé de prolonger mon séjour et de visiter {} pour en apprendre davantage sur son histoire.",
        "En passant par {}, j'ai été transporté(e) dans un monde de saveurs culinaires avant de continuer mon périple jusqu'à {}.",
        "Mon voyage de {} à {} m'a permis de constater la diversité incroyable des paysages rencontrés en chemin.",
        "Après avoir visité {}, j'ai ressenti le besoin de me rendre à {} pour une retraite paisible en pleine nature.",
        "J'ai choisi {} comme prochaine destination après être passé(e) par {} où j'ai découvert des traditions ancestrales.",
        "Entre {} et {}, j'ai été émerveillé(e) par la richesse artistique et culturelle de ces lieux.",
        "Après avoir contemplé {}, j'ai entrepris de visiter {} pour explorer ses merveilles cachées.",
        "En découvrant {}, j'ai été attiré(e) par {} et sa réputation de ville animée et cosmopolite.",
        "Après {} est venu {} dans mon itinéraire, m'offrant une transition parfaite entre deux expériences uniques.",
        "J'ai exploré {} avant de me diriger vers {} pour une immersion dans des paysages à couper le souffle.",
        "Ma route m'a conduit(e) de {} à {} où j'ai eu la chance de participer à des festivités locales.",
        "Après mon séjour à {}, j'ai continué vers {} pour une expérience gastronomique exceptionnelle.",
        "J'ai voyagé de {} à {} pour découvrir de nouvelles coutumes et traditions fascinantes.",
        "De {} jusqu'à {}, mon trajet a été ponctué de découvertes surprenantes qui ont enrichi mon expérience.",
        "En partant de {} pour aller à {}, j'ai vécu des rencontres humaines uniques et enrichissantes.",
        "J'ai exploré {} avant de découvrir {} où j'ai été plongé(e) dans une atmosphère vibrante et dynamique.",
        "De {} à {}, j'ai fait une escale enrichissante où j'ai pu participer à des activités traditionnelles.",
        "Après mon passage à {}, je suis parti(e) pour {} pour une expérience de détente et de bien-être.",
        "J'ai continué mon voyage de {} à {} où j'ai été impressionné(e) par la modernité et l'effervescence de la ville.",
        "{} m'a enchanté(e) avant d'atteindre {} où j'ai été émerveillé(e) par son patrimoine historique.",
        "Après avoir exploré {}, je suis parti(e) à {} pour un séjour de ressourcement au cœur de la nature.",
        "En passant de {} à {}, j'ai rencontré des guides locaux passionnés qui m'ont fait découvrir des endroits secrets.",
        "Lors de mon voyage, de {} à {}, j'ai découvert de nouveaux horizons qui ont élargi ma perception du monde.",
        "Parti(e) de {} et arrivé(e) à {}, un voyage parsemé de découvertes culturelles et humaines.",
        "En partant de {}, je me suis dirigé(e) vers {} pour une immersion dans des traditions ancestrales.",
        "C'est de {} à {} que j'ai tracé mon itinéraire, m'offrant une diversité d'expériences inoubliables.",
        "Après avoir quitté {}, je me suis dirigé(e) vers {} pour une aventure en pleine nature.",
        "J'ai choisi de passer par {} avant d'explorer {} et d'y découvrir une scène artistique bouillonnante.",
        "En visitant {} et ensuite {}, j'ai appris à connaître les différentes facettes d'un même pays.",
        "Ils ont exploré {} avant de se diriger vers {} pour un séjour reposant au bord de la mer.",
        "Elles ont parcouru un long chemin de {} à {} où elles ont découvert une hospitalité exceptionnelle.",
        "Il est allé de {} à {} pour ses vacances et y a trouvé une atmosphère de fête permanente.",
        "Elle est partie de {} pour découvrir {} et y a rencontré une communauté accueillante et chaleureuse.",
        "On a visité {} et ensuite {} pour une expérience culinaire inégalée.",
        "Vous êtes allé(e) de {} à {} pour une aventure sportive et de plein air.",
        "Après avoir exploré {}, j'ai été attiré(e) par {} pour sa riche histoire.",
        "En débutant mon voyage à {}, j'ai été immédiatement séduit(e) par l'atmosphère vibrante de la ville avant d'arriver à {}.",
        "De {}, j'ai entrepris un périple jusqu'à {} pour découvrir sa culture unique et ses traditions anciennes.",
        "Après un séjour enrichissant à {}, j'ai pris la décision de me rendre à {} pour son paysage époustouflant.",
        "Ma visite à {} m'a inspiré(e) à explorer les trésors cachés de {}.",
        "En passant par {}, j'ai été émerveillé(e) par la diversité des expériences que cette région offre avant de poursuivre vers {}.",
        "Après avoir découvert les merveilles de {} et y avoir passé du temps, j'ai poursuivi mon voyage vers {} pour une expérience totalement différente.",
        "De {} à {}, chaque étape était une aventure unique où j'ai rencontré des gens formidables et découvert des traditions fascinantes.",
        "J'ai quitté ma ville natale de {} pour me plonger dans l'effervescence de {} et sa vie nocturne animée.",
        "Après avoir contemplé la beauté naturelle de {}, j'ai choisi de me rendre à {} pour explorer ses monuments historiques.",
        "J'ai entrepris mon voyage de {} à {}.",
        "{} m'a enchanté(e) avant d'atteindre {}.",
        "J'ai choisi de passer par {} avant d'explorer {}.",
        "Je suis allé(e) de {} à {}.",
        "J'ai visité {} avant de découvrir {}.",
        "Mon voyage m'a mené de {} à {}.",
        "En passant par {}, j'ai finalement atteint {}.",
        "À la suite de mon passage à {}, j'ai décidé de visiter {}.",
        "De {} jusqu'à {}, chaque étape était une aventure.",
        "Après avoir découvert {}, j'ai décidé de me rendre à {}.",
        "J'ai choisi {} comme prochaine destination après {}.",
        "Entre {} et {}, j'ai découvert des endroits merveilleux.",
        "J'ai quitté {} pour me diriger vers {}.",
        "Après avoir admiré {}, j'ai entrepris d'explorer {}.",
        "De {} à {}, j'ai vécu des moments inoubliables.",
        "Je suis passé(e) de {} à {} pour découvrir de nouveaux horizons.",
        "À la suite de ma visite à {}, j'ai décidé de me rendre à {}.",
        "Entre {} et {}, j'ai rencontré des personnes formidables.",
        "J'ai quitté {} pour m'aventurer à {}.",
        "Après avoir contemplé {}, j'ai décidé de visiter {}.",
        "Mon itinéraire m'a mené de {} à {}.",
        "En partant de {}, je me suis dirigé(e) vers {}.",
        "De {} à {}, chaque étape a été une source d'émerveillement.",
        "Après avoir exploré {}, j'ai continué ma route jusqu'à {}.",
        "En quittant {}, je suis allé(e) à {} pour découvrir de nouveaux paysages.",
        "Entre {} et {}, j'ai découvert une richesse culturelle incroyable.",
        "J'ai décidé de partir de {} pour me rendre à {}.",
        "Après avoir découvert {}, je me suis dirigé(e) vers {}.",
        "Ma visite à {} m'a inspiré(e) à explorer {}.",
        "En voyageant de {} à {}, j'ai été émerveillé(e) par la diversité.",
        "Après avoir contemplé {}, j'ai entrepris de visiter {}.",
        "Je suis allé(e) de {} jusqu'à {} pour explorer de nouveaux lieux.",
        "Après avoir passé du temps à {}, j'ai décidé de me rendre à {}.",
        "En découvrant {}, j'ai été attiré(e) par {}.",
        "De {} à {}, j'ai apprécié chaque moment de mon périple.",
        "Après avoir exploré {}, j'ai décidé de découvrir {}.",
        "Mon itinéraire m'a conduit de {} à {} pour une expérience unique.",
        "Après avoir visité {}, j'ai poursuivi mon voyage jusqu'à {}.",
        "J'ai choisi {} comme prochaine étape après être passé(e) par {}.",
        "De {} à {}, j'ai été fasciné(e) par la diversité des paysages.",
        "Après avoir découvert {}, j'ai décidé de me rendre à {} pour en voir plus.",
        "En voyageant de {} à {}, j'ai été surpris(e) par la richesse culturelle.",
        "Après avoir exploré {}, j'ai entrepris de découvrir {}.",
        "Je suis passé(e) de {} à {} pour une expérience enrichissante.",
        "Après avoir visité {}, j'ai poursuivi mon périple jusqu'à {}.",
        "En quittant {}, je me suis dirigé(e) vers {} pour de nouvelles découvertes.",
        "J'ai choisi {} comme prochaine destination après être passé(e) par {}.",
        "De {} à {}, j'ai été captivé(e) par la beauté des lieux.",
        "Après avoir passé du temps à {}, j'ai décidé de visiter {}.",
        "Mon voyage de {} à {} m'a offert une diversité incroyable.",
        "En partant de {}, je me suis rendu(e) à {} pour de nouvelles aventures.",
        "Après avoir découvert {}, j'ai décidé de me rendre à {} pour en voir plus.",
        "En voyageant de {} à {}, j'ai été surpris(e) par la richesse culturelle.",
        "Après avoir exploré {}, j'ai entrepris de découvrir {}.",
        "Je suis passé(e) de {} à {} pour une expérience enrichissante.",
        "Après avoir visité {}, j'ai poursuivi mon périple jusqu'à {}.",
        "En quittant {}, je me suis dirigé(e) vers {} pour de nouvelles découvertes.",
        "J'ai choisi {} comme prochaine destination après être passé(e) par {}.",
        "De {} à {}, j'ai été captivé(e) par la beauté des lieux.",
        "Après avoir passé du temps à {}, j'ai décidé de visiter {}.",
        "Mon voyage de {} à {} m'a offert une diversité incroyable.",
        "En partant de {}, je me suis rendu(e) à {} pour de nouvelles aventures.",
        "Je suis allé(e) de {} à {}.",
        "J'ai visité {} avant de découvrir {}.",
        "Après avoir exploré {}, je suis parti(e) à {}.",
        "De {} à {}, j'ai parcouru un long chemin.",
        "À la suite de mon séjour à {}, j'ai voyagé jusqu'à {}.",
        "Mon périple m'a mené de {} à {}.",
        "Je me suis rendu(e) de {} vers {}.",
        "Après {} est venu(e) {} lors de mon voyage.",
        "J'ai quitté {} pour me rendre à {}.",
        "En partant de {}, je suis arrivé(e) à {}.",
        "De {} jusqu'à {}, mon itinéraire était passionnant.",
        "J'ai exploré {} avant de me diriger vers {}.",
        "Ma route m'a conduit(e) de {} à {}.",
        "De {} à {}, j'ai découvert de nouveaux horizons.",
        "Après mon séjour à {}, j'ai continué vers {}.",
        "J'ai voyagé de {} à {} pour découvrir de nouvelles cultures.",
        "De {} jusqu'à {}, mon trajet a été plein de surprises.",
        "En partant de {} pour aller à {}, j'ai vécu des aventures incroyables.",
        "J'ai exploré {} avant de me rendre à {}.",
        "J'ai découvert {} après être passé(e) par {}.",
        "De {} à {}, j'ai fait un saut inattendu.",
        "En quittant {}, je me suis dirigé(e) vers {}.",
        "De {} à {}, j'ai fait une escale enrichissante.",
        "Après mon passage à {}, je suis parti(e) pour {}.",
        "J'ai continué mon voyage de {} à {}.",
        "De {} à {}, j'ai exploré de nouveaux horizons.",
        "Après {} est venu {} lors de mon périple.",
        "De {} à {}, j'ai fait une pause avant de repartir vers {}.",
        "J'ai fait étape à {} avant de me rendre à {}.",
        "En partant de {}, je suis arrivé(e) à {}.",
        "J'ai exploré {} avant de me diriger vers {}.",
        "Ma route m'a conduit(e) de {} à {}.",
        "De {} à {}, j'ai découvert de nouveaux horizons.",
        "Après mon séjour à {}, j'ai continué vers {}.",
        "J'ai voyagé de {} à {} pour découvrir de nouvelles cultures.",
        "De {} jusqu'à {}, mon trajet a été plein de surprises.",
        "En partant de {} pour aller à {}, j'ai vécu des aventures incroyables.",
        "Ma visite à {} a été suivie par un passage à {}.",
        "De {} à {}, j'ai apprécié chaque étape de mon voyage.",
        "Après avoir quitté {}, je me suis dirigé(e) vers {}.",
        "J'ai entrepris mon voyage de {} à {}.",
        "En passant de {} à {}, j'ai rencontré des personnes formidables.",
        "De {} à {}, mon parcours a été riche en découvertes.",
        "Après {} vient {} dans mon itinéraire.",
        "J'ai découvert {} après être passé(e) par {}.",
        "De {} à {}, j'ai fait un saut inattendu.",
        "En quittant {}, je me suis dirigé(e) vers {}.",
        "De {} à {}, j'ai fait une escale enrichissante.",
        "Après mon passage à {}, je suis parti(e) pour {}.",
        "J'ai continué mon voyage de {} à {}.",
        "De {} à {}, j'ai exploré de nouveaux horizons.",
        "Après {} est venu {} lors de mon périple.",
        "De {} à {}, j'ai fait une pause avant de repartir vers {}.",
        "J'ai fait étape à {} avant de me rendre à {}.",
        "Après avoir exploré {}, je suis parti(e) à {}.",
        "De {} à {}, j'ai parcouru un long chemin.",
        "À la suite de mon séjour à {}, j'ai voyagé jusqu'à {}.",
        "En partant de {}, je me suis rendu(e) à {}.",
        "Mon voyage de {} à {} était incroyable.",
        "Lors de mon passage de {} à {}, j'ai été émerveillé(e).",
        "Nous avons voyagé de {} à {} ensemble.",
        "En visitant {} et ensuite {}, j'ai appris beaucoup de choses.",
        "Ils ont exploré {} avant de se diriger vers {}.",
        "Elles ont parcouru un long chemin de {} à {}.",
        "Il est allé de {} à {} pour ses vacances.",
        "Elle est partie de {} pour découvrir {}.",
        "On a visité {} et ensuite {} pour une expérience inoubliable.",
        "Vous êtes allé(e) de {} à {} pour vos vacances.",
        "En passant de {} à {}, tu as trouvé quelque chose d'intéressant.",
        "Lors de votre séjour de {} à {}, vous avez vu beaucoup de choses.",
        "Ils ont voyagé de {} à {} pour affaires.",
        "Elles sont parties de {} à {} pour une escapade.",
        "Il a parcouru un long chemin de {} à {}.",
        "Elle a découvert {} après avoir visité {}.",
        "On est allé de {} à {} pour des raisons spéciales.",
        "Nous sommes partis de {} à {} pour explorer.",
        "En visitant {} et ensuite {}, nous avons réalisé beaucoup de choses.",
        "Vous avez exploré {} avant de vous rendre à {}.",
        "En passant de {} à {}, vous avez eu une aventure incroyable.",
        "Ils sont partis de {} à {} pour des vacances reposantes.",
        "Elles ont voyagé de {} à {} pour une expérience enrichissante.",
        "Il est allé de {} à {} pour se ressourcer.",
        "Elle est partie de {} pour découvrir {} et s'y installer.",
        "On a visité {} et ensuite {} pour une escapade culturelle.",
        "Vous êtes allé(e) de {} à {} pour un changement de paysage.",
        "En passant de {} à {}, tu as découvert de nouvelles perspectives.",
        "Lors de votre séjour de {} à {}, vous avez vécu des moments uniques.",
        "Ils ont voyagé de {} à {} pour des affaires importantes.",
        "Elles sont parties de {} à {} pour une aventure mémorable.",
        "Lors de mon voyage, de {} à {}, j'ai découvert de nouveaux horizons.",
        "Parti(e) de {} et arrivé(e) à {}, un voyage inoubliable.",
        "En partant de {}, je me suis dirigé(e) vers {}.",
        "C'est de {} à {} que j'ai tracé mon itinéraire.",
        "{} m'a enchanté(e) avant d'atteindre {}.",
        "J'ai choisi de passer par {} avant d'explorer {}."
        "J'ai choisi de passer par {}.",
    ]

# %%
sentences = []

# %%
for _ in range(len(patterns)):
        pattern = random.choice(patterns)  # Sélection aléatoire d'un modèle de phrase
        pattern_elements = pattern.count(
            "{}"
        )  # Compter le nombre d'emplacements à remplir
        available_cities = villes["name"].tolist()

        if pattern_elements > len(available_cities):
            pattern_elements = len(available_cities)

        replacements = random.sample(
            available_cities, pattern_elements
        )  # Sélectionner les éléments à remplacer
        line = pattern.format(
            *replacements
        )  # Formater la phrase avec les éléments sélectionnés

        line_without_spaces = line.replace(" ", "")

        sentences.append(
            {
                "TEXT": line,
                "DEPART": replacements[0],
                "START_DEPART": line.find(replacements[0]) + 1,
                "END_DEPART": len(replacements[0]) + line.find(replacements[0]),
                "DEP": "DEP",
                "DESTINATION": replacements[1],
                "START_DEST": line.find(replacements[1]) + 1,
                "END_DEST": line.find(replacements[1]) + len(replacements[1]),
                "DEST": "DEST",
            }
        )

# %%
sentences
# Out:
# [{'TEXT': "En passant par MalguÃ©nac, j'ai été ébloui(e) par la diversité architecturale avant de me rendre à Le Conquet pour explorer les traditions locales.",
#   'DEPART': 'MalguÃ©nac',
#   'START_DEPART': 16,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Le Conquet',
#   'START_DEST': 100,
#   'END_DEST': 109,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Kergrist-MoÃ«lou, j'ai poursuivi mon périple jusqu'à Vignemont.",
#   'DEPART': 'Kergrist-MoÃ«lou',
#   'START_DEPART': 20,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vignemont',
#   'START_DEST': 73,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "De Brigueuil jusqu'à Villaines-la-Gonais, chaque étape de mon itinéraire a été marquée par des rencontres inspirantes.",
#   'DEPART': 'Brigueuil',
#   'START_DEPART': 4,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Villaines-la-Gonais',
#   'START_DEST': 22,
#   'END_DEST': 40,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de partir de Pouzolles pour me rendre à Vauthiermont.",
#   'DEPART': 'Pouzolles',
#   'START_DEPART': 26,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vauthiermont',
#   'START_DEST': 53,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "De Voulx à Ã\x89trÃ©ville, j'ai fait un saut inattendu.",
#   'DEPART': 'Voulx',
#   'START_DEPART': 4,
#   'END_DEPART': 8,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ã\x89trÃ©ville',
#   'START_DEST': 12,
#   'END_DEST': 22,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité les musées de Archipel des Crozet, j'ai décidé de m'aventurer vers Vadencourt pour une expérience artistique différente.",
#   'DEPART': 'Archipel des Crozet',
#   'START_DEPART': 34,
#   'END_DEPART': 52,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vadencourt',
#   'START_DEST': 87,
#   'END_DEST': 96,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire un détour par Saint-Georges-les-Landes pour un moment de détente avant de poursuivre vers Bistroff pour de nouvelles découvertes.",
#   'DEPART': 'Saint-Georges-les-Landes',
#   'START_DEPART': 36,
#   'END_DEPART': 59,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bistroff',
#   'START_DEST': 112,
#   'END_DEST': 119,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai entrepris mon voyage de Neauphlette à Athos-Aspis.",
#   'DEPART': 'Neauphlette',
#   'START_DEPART': 30,
#   'END_DEPART': 40,
#   'DEP': 'DEP',
#   'DESTINATION': 'Athos-Aspis',
#   'START_DEST': 44,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir profité des paysages spectaculaires de Saint-MÃ©dard-d'Eyrans, j'ai repris la route vers VallÃ¨gue.",
#   'DEPART': "Saint-MÃ©dard-d'Eyrans",
#   'START_DEPART': 52,
#   'END_DEPART': 73,
#   'DEP': 'DEP',
#   'DESTINATION': 'VallÃ¨gue',
#   'START_DEST': 102,
#   'END_DEST': 110,
#   'DEST': 'DEST'},
#  {'TEXT': "De Hesdin-l'AbbÃ© à Montcarra, j'ai été subjugué(e) par la fusion parfaite entre tradition et modernité.",
#   'DEPART': "Hesdin-l'AbbÃ©",
#   'START_DEPART': 4,
#   'END_DEPART': 17,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montcarra',
#   'START_DEST': 21,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': 'Mon voyage de Sotzeling à Girolles était incroyable.',
#   'DEPART': 'Sotzeling',
#   'START_DEPART': 15,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Girolles',
#   'START_DEST': 27,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': "De Seyssuel à Brouchaud, j'ai découvert de nouveaux horizons.",
#   'DEPART': 'Seyssuel',
#   'START_DEPART': 4,
#   'END_DEPART': 11,
#   'DEP': 'DEP',
#   'DESTINATION': 'Brouchaud',
#   'START_DEST': 15,
#   'END_DEST': 23,
#   'DEST': 'DEST'},
#  {'TEXT': "Je suis allé(e) de Saint-Pierre-d'Amilly à Fontaine-Couverte.",
#   'DEPART': "Saint-Pierre-d'Amilly",
#   'START_DEPART': 20,
#   'END_DEPART': 40,
#   'DEP': 'DEP',
#   'DESTINATION': 'Fontaine-Couverte',
#   'START_DEST': 44,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré Cogolin, je suis parti(e) à Vernou-en-Sologne.',
#   'DEPART': 'Cogolin',
#   'START_DEPART': 21,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vernou-en-Sologne',
#   'START_DEST': 49,
#   'END_DEST': 65,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi Lyon comme prochaine destination après être passé(e) par Serre-les-MouliÃ¨res où j'ai découvert des traditions ancestrales.",
#   'DEPART': 'Lyon',
#   'START_DEPART': 13,
#   'END_DEPART': 16,
#   'DEP': 'DEP',
#   'DESTINATION': 'Serre-les-MouliÃ¨res',
#   'START_DEST': 70,
#   'END_DEST': 89,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple m'a mené de Beaune-d'Allier à Montfort.",
#   'DEPART': "Beaune-d'Allier",
#   'START_DEPART': 25,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montfort',
#   'START_DEST': 43,
#   'END_DEST': 50,
#   'DEST': 'DEST'},
#  {'TEXT': "Après mon séjour à MÃ©neslies, j'ai continué vers Montreuil-Bellay pour une expérience gastronomique exceptionnelle.",
#   'DEPART': 'MÃ©neslies',
#   'START_DEPART': 20,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montreuil-Bellay',
#   'START_DEST': 51,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Autreville-sur-la-Renne à Hinsbourg m'a permis de constater la diversité incroyable des paysages rencontrés en chemin.",
#   'DEPART': 'Autreville-sur-la-Renne',
#   'START_DEPART': 15,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Hinsbourg',
#   'START_DEST': 41,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir contemplé la beauté naturelle de PÃ©rignat-sur-Allier, j'ai choisi de me rendre à Silley-BlÃ©fond pour explorer ses monuments historiques.",
#   'DEPART': 'PÃ©rignat-sur-Allier',
#   'START_DEPART': 46,
#   'END_DEPART': 65,
#   'DEP': 'DEP',
#   'DESTINATION': 'Silley-BlÃ©fond',
#   'START_DEST': 95,
#   'END_DEST': 109,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les traditions uniques de Pont-et-MassÃ¨ne, j'ai continué vers MisÃ©rieux pour vivre de nouvelles expériences.",
#   'DEPART': 'Pont-et-MassÃ¨ne',
#   'START_DEPART': 49,
#   'END_DEPART': 64,
#   'DEP': 'DEP',
#   'DESTINATION': 'MisÃ©rieux',
#   'START_DEST': 86,
#   'END_DEST': 95,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir quitté Tardets-Sorholus, je me suis dirigé(e) vers Saint-Bonnet-de-Rochefort.',
#   'DEPART': 'Tardets-Sorholus',
#   'START_DEPART': 20,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Bonnet-de-Rochefort',
#   'START_DEST': 64,
#   'END_DEST': 88,
#   'DEST': 'DEST'},
#  {'TEXT': "De Paris à Cravanche, j'ai fait un saut inattendu.",
#   'DEPART': 'Paris',
#   'START_DEPART': 4,
#   'END_DEPART': 8,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cravanche',
#   'START_DEST': 12,
#   'END_DEST': 20,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré les rues animées de Agnat, j'ai savouré la tranquillité de Franvillers.",
#   'DEPART': 'Agnat',
#   'START_DEPART': 41,
#   'END_DEPART': 45,
#   'DEP': 'DEP',
#   'DESTINATION': 'Franvillers',
#   'START_DEST': 80,
#   'END_DEST': 90,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté ma ville natale de Jugy pour me plonger dans l'effervescence de Verneil-le-ChÃ©tif et sa vie nocturne animée.",
#   'DEPART': 'Jugy',
#   'START_DEPART': 32,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Verneil-le-ChÃ©tif',
#   'START_DEST': 77,
#   'END_DEST': 94,
#   'DEST': 'DEST'},
#  {'TEXT': 'Ils ont voyagé de Montlaur à La Grande-RÃ©sie pour des affaires importantes.',
#   'DEPART': 'Montlaur',
#   'START_DEPART': 19,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'La Grande-RÃ©sie',
#   'START_DEST': 30,
#   'END_DEST': 45,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Cros, j'ai été captivé(e) par la beauté naturelle avant de me rendre à Oris-en-Rattier pour une aventure inattendue.",
#   'DEPART': 'Cros',
#   'START_DEPART': 16,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Oris-en-Rattier',
#   'START_DEST': 87,
#   'END_DEST': 101,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré Pogny, je suis parti(e) à La Guillermie pour un séjour de ressourcement au cœur de la nature.',
#   'DEPART': 'Pogny',
#   'START_DEPART': 21,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'La Guillermie',
#   'START_DEST': 47,
#   'END_DEST': 59,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Bran, j'ai finalement atteint Cholonge.",
#   'DEPART': 'Bran',
#   'START_DEPART': 16,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cholonge',
#   'START_DEST': 46,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Le Gault-du-Perche, je me suis dirigé(e) vers Ronchamp.',
#   'DEPART': 'Le Gault-du-Perche',
#   'START_DEPART': 13,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ronchamp',
#   'START_DEST': 59,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert Arnancourt, j'ai décidé de prolonger mon séjour et de visiter AnthÃ© pour en apprendre davantage sur son histoire.",
#   'DEPART': 'Arnancourt',
#   'START_DEPART': 23,
#   'END_DEPART': 32,
#   'DEP': 'DEP',
#   'DESTINATION': 'AnthÃ©',
#   'START_DEST': 85,
#   'END_DEST': 90,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir découvert Servignat, je me suis dirigé(e) vers Ourches.',
#   'DEPART': 'Servignat',
#   'START_DEPART': 23,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ourches',
#   'START_DEST': 60,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "De Glay à Saint-Lambert, j'ai suivi les traces des explorateurs anciens tout en explorant des attractions modernes.",
#   'DEPART': 'Glay',
#   'START_DEPART': 4,
#   'END_DEPART': 7,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Lambert',
#   'START_DEST': 11,
#   'END_DEST': 23,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir profité des paysages spectaculaires de Dommartin-lÃ¨s-Cuiseaux, j'ai repris la route vers RoyÃ¨re-de-VassiviÃ¨re.",
#   'DEPART': 'Dommartin-lÃ¨s-Cuiseaux',
#   'START_DEPART': 52,
#   'END_DEPART': 74,
#   'DEP': 'DEP',
#   'DESTINATION': 'RoyÃ¨re-de-VassiviÃ¨re',
#   'START_DEST': 103,
#   'END_DEST': 124,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir découvert Culin, je me suis dirigé(e) vers Le Pont-de-Beauvoisin.',
#   'DEPART': 'Culin',
#   'START_DEPART': 23,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Le Pont-de-Beauvoisin',
#   'START_DEST': 56,
#   'END_DEST': 76,
#   'DEST': 'DEST'},
#  {'TEXT': 'Lors de votre séjour de Saint-Maugan à Roy-Boissy, vous avez vu beaucoup de choses.',
#   'DEPART': 'Saint-Maugan',
#   'START_DEPART': 25,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Roy-Boissy',
#   'START_DEST': 40,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les richesses artistiques de Mosnac, j'ai pris la direction de Richeling pour une immersion différente.",
#   'DEPART': 'Mosnac',
#   'START_DEPART': 52,
#   'END_DEPART': 57,
#   'DEP': 'DEP',
#   'DESTINATION': 'Richeling',
#   'START_DEST': 86,
#   'END_DEST': 94,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant de Anzy-le-Duc à Boussy, j'ai rencontré des personnes formidables.",
#   'DEPART': 'Anzy-le-Duc',
#   'START_DEPART': 15,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Boussy',
#   'START_DEST': 29,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Aigremont à GuÃ©thary pour un changement de paysage.',
#   'DEPART': 'Aigremont',
#   'START_DEPART': 22,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'GuÃ©thary',
#   'START_DEST': 34,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Vellerot-lÃ¨s-Vercel, je me suis rendu(e) à Gamarthe pour de nouvelles aventures.',
#   'DEPART': 'Vellerot-lÃ¨s-Vercel',
#   'START_DEPART': 15,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Gamarthe',
#   'START_DEST': 59,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Peyrus, j'ai été séduit(e) par les festivals culturels avant de me rendre à Lugaignac pour des escapades rurales.",
#   'DEPART': 'Peyrus',
#   'START_DEPART': 16,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Lugaignac',
#   'START_DEST': 92,
#   'END_DEST': 100,
#   'DEST': 'DEST'},
#  {'TEXT': "Entre Jonchery-sur-Vesle et Vic-des-PrÃ©s, j'ai rencontré des personnes formidables.",
#   'DEPART': 'Jonchery-sur-Vesle',
#   'START_DEPART': 7,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vic-des-PrÃ©s',
#   'START_DEST': 29,
#   'END_DEST': 41,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire une halte à Baudignan pour une expérience culturelle unique avant de rejoindre Caignac pour la suite de mon voyage.",
#   'DEPART': 'Baudignan',
#   'START_DEPART': 34,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Caignac',
#   'START_DEST': 101,
#   'END_DEST': 107,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir découvert Tardets-Sorholus, je me suis dirigé(e) vers Oberlauterbach.',
#   'DEPART': 'Tardets-Sorholus',
#   'START_DEPART': 23,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'Oberlauterbach',
#   'START_DEST': 67,
#   'END_DEST': 80,
#   'DEST': 'DEST'},
#  {'TEXT': "Ma visite à Martres m'a inspiré(e) à explorer Caurel.",
#   'DEPART': 'Martres',
#   'START_DEPART': 13,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Caurel',
#   'START_DEST': 47,
#   'END_DEST': 52,
#   'DEST': 'DEST'},
#  {'TEXT': "Après mon séjour à Chazelles, j'ai continué vers Tieste-Uragnoux.",
#   'DEPART': 'Chazelles',
#   'START_DEPART': 20,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Tieste-Uragnoux',
#   'START_DEST': 50,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': 'Lors de votre séjour de Lortet à Saint-RÃ©my, vous avez vu beaucoup de choses.',
#   'DEPART': 'Lortet',
#   'START_DEPART': 25,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-RÃ©my',
#   'START_DEST': 34,
#   'END_DEST': 44,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai entrepris mon voyage de Saint-Goussaud à Genvry.",
#   'DEPART': 'Saint-Goussaud',
#   'START_DEPART': 30,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Genvry',
#   'START_DEST': 47,
#   'END_DEST': 52,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Saint-RÃ©my-au-Bois, j'ai suivi un chemin sinueux pour finalement arriver à Valojoulx et être ébloui(e) par sa beauté naturelle.",
#   'DEPART': 'Saint-RÃ©my-au-Bois',
#   'START_DEPART': 15,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Valojoulx',
#   'START_DEST': 91,
#   'END_DEST': 99,
#   'DEST': 'DEST'},
#  {'TEXT': "Le Mesnil-sous-JumiÃ¨ges m'a enchanté(e) avant d'atteindre Supt.",
#   'DEPART': 'Le Mesnil-sous-JumiÃ¨ges',
#   'START_DEPART': 1,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Supt',
#   'START_DEST': 60,
#   'END_DEST': 63,
#   'DEST': 'DEST'},
#  {'TEXT': 'Il est allé de Choqueuse-les-BÃ©nards à Ommeray pour se ressourcer.',
#   'DEPART': 'Choqueuse-les-BÃ©nards',
#   'START_DEPART': 16,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ommeray',
#   'START_DEST': 41,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': 'Il est allé de Anais à Bellefont-La Rauze pour ses vacances.',
#   'DEPART': 'Anais',
#   'START_DEPART': 16,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bellefont-La Rauze',
#   'START_DEST': 24,
#   'END_DEST': 41,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai commencé mon voyage à Castres où j'ai été plongé(e) dans une ambiance authentique avant de me rendre à Dreuilhe pour explorer davantage.",
#   'DEPART': 'Castres',
#   'START_DEPART': 28,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Dreuilhe',
#   'START_DEST': 109,
#   'END_DEST': 116,
#   'DEST': 'DEST'},
#  {'TEXT': 'Ils ont voyagé de Carresse-Cassaber à Montesquieu-Guittaut pour des affaires importantes.',
#   'DEPART': 'Carresse-Cassaber',
#   'START_DEPART': 19,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montesquieu-Guittaut',
#   'START_DEST': 39,
#   'END_DEST': 58,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Bastennes à Les Bondons m'a offert une diversité incroyable.",
#   'DEPART': 'Bastennes',
#   'START_DEPART': 15,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Les Bondons',
#   'START_DEST': 27,
#   'END_DEST': 37,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Arcinges à Han-lÃ¨s-Juvigny m'a offert une diversité incroyable.",
#   'DEPART': 'Arcinges',
#   'START_DEPART': 15,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Han-lÃ¨s-Juvigny',
#   'START_DEST': 26,
#   'END_DEST': 41,
#   'DEST': 'DEST'},
#  {'TEXT': "Elle est partie de Luppy pour découvrir Braquis et s'y installer.",
#   'DEPART': 'Luppy',
#   'START_DEPART': 20,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Braquis',
#   'START_DEST': 41,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': 'Ils ont exploré Gorze avant de se diriger vers GÃ©fosse-Fontenay pour un séjour reposant au bord de la mer.',
#   'DEPART': 'Gorze',
#   'START_DEPART': 17,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'GÃ©fosse-Fontenay',
#   'START_DEST': 48,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Saussay-la-Campagne à Saint-Andelain m'a offert une diversité incroyable.",
#   'DEPART': 'Saussay-la-Campagne',
#   'START_DEPART': 15,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Andelain',
#   'START_DEST': 37,
#   'END_DEST': 50,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant de Ceaux-en-Loudun à Reichstett, j'ai rencontré des guides locaux passionnés qui m'ont fait découvrir des endroits secrets.",
#   'DEPART': 'Ceaux-en-Loudun',
#   'START_DEPART': 15,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Reichstett',
#   'START_DEST': 33,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Allery, je suis arrivé(e) à Furchhausen.',
#   'DEPART': 'Allery',
#   'START_DEPART': 15,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Furchhausen',
#   'START_DEST': 43,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Flavy-le-Meldeux, j'ai exploré les marchés locaux avant de me rendre à Pont-de-Ruan pour une immersion dans la cuisine régionale.",
#   'DEPART': 'Flavy-le-Meldeux',
#   'START_DEPART': 16,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pont-de-Ruan',
#   'START_DEST': 87,
#   'END_DEST': 98,
#   'DEST': 'DEST'},
#  {'TEXT': "En quittant Sionne, j'ai été fasciné(e) par l'héritage historique avant de m'immerger dans la modernité de BÃ©guey.",
#   'DEPART': 'Sionne',
#   'START_DEPART': 13,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'BÃ©guey',
#   'START_DEST': 108,
#   'END_DEST': 114,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Saint-Julia, j'ai finalement atteint Lauzach.",
#   'DEPART': 'Saint-Julia',
#   'START_DEPART': 16,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Lauzach',
#   'START_DEST': 53,
#   'END_DEST': 59,
#   'DEST': 'DEST'},
#  {'TEXT': 'Nous sommes partis de Saint-Martin-de-BonfossÃ© à Neuvy-Saint-SÃ©pulchre pour explorer.',
#   'DEPART': 'Saint-Martin-de-BonfossÃ©',
#   'START_DEPART': 23,
#   'END_DEPART': 47,
#   'DEP': 'DEP',
#   'DESTINATION': 'Neuvy-Saint-SÃ©pulchre',
#   'START_DEST': 51,
#   'END_DEST': 72,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir profité de la convivialité de Granges-Aumontzey, j'ai repris ma route vers Dun-sur-Meuse pour découvrir de nouvelles perspectives.",
#   'DEPART': 'Granges-Aumontzey',
#   'START_DEPART': 43,
#   'END_DEPART': 59,
#   'DEP': 'DEP',
#   'DESTINATION': 'Dun-sur-Meuse',
#   'START_DEST': 88,
#   'END_DEST': 100,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré les rues animées de Lestiac-sur-Garonne, j'ai savouré la tranquillité de Mirabel.",
#   'DEPART': 'Lestiac-sur-Garonne',
#   'START_DEPART': 41,
#   'END_DEPART': 59,
#   'DEP': 'DEP',
#   'DESTINATION': 'Mirabel',
#   'START_DEST': 94,
#   'END_DEST': 100,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité ChÃ¢rost, j'ai poursuivi mon périple jusqu'à Authe.",
#   'DEPART': 'ChÃ¢rost',
#   'START_DEPART': 20,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Authe',
#   'START_DEST': 65,
#   'END_DEST': 69,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les merveilles de Saint-Georges-sur-Erve et y avoir passé du temps, j'ai poursuivi mon voyage vers Ougney pour une expérience totalement différente.",
#   'DEPART': 'Saint-Georges-sur-Erve',
#   'START_DEPART': 41,
#   'END_DEPART': 62,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ougney',
#   'START_DEST': 122,
#   'END_DEST': 127,
#   'DEST': 'DEST'},
#  {'TEXT': "C'est de Val-Cenis à Appietto que j'ai tracé mon itinéraire, m'offrant une diversité d'expériences inoubliables.",
#   'DEPART': 'Val-Cenis',
#   'START_DEPART': 10,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Appietto',
#   'START_DEST': 22,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant RÃ©chicourt-le-ChÃ¢teau, je suis allé(e) à Perrier pour découvrir de nouveaux paysages.',
#   'DEPART': 'RÃ©chicourt-le-ChÃ¢teau',
#   'START_DEPART': 13,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Perrier',
#   'START_DEST': 56,
#   'END_DEST': 62,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Paris, je me suis dirigé(e) vers Saint-Maurice-de-Cazevieille pour de nouvelles découvertes.',
#   'DEPART': 'Paris',
#   'START_DEPART': 13,
#   'END_DEPART': 17,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Maurice-de-Cazevieille',
#   'START_DEST': 46,
#   'END_DEST': 73,
#   'DEST': 'DEST'},
#  {'TEXT': "De Kaltenhouse jusqu'à Bassemberg, j'ai parcouru des terres fertiles et des déserts arides pour une expérience contrastée.",
#   'DEPART': 'Kaltenhouse',
#   'START_DEPART': 4,
#   'END_DEPART': 14,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bassemberg',
#   'START_DEST': 24,
#   'END_DEST': 33,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré les quartiers colorés de Montignac, j'ai pris la route vers Cras pour une plongée dans la diversité culturelle.",
#   'DEPART': 'Montignac',
#   'START_DEPART': 46,
#   'END_DEPART': 54,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cras',
#   'START_DEST': 81,
#   'END_DEST': 84,
#   'DEST': 'DEST'},
#  {'TEXT': "En découvrant les coutumes authentiques de Le Val-Saint-PÃ¨re, j'ai poursuivi mon périple vers Saint-Martin-de-ConnÃ©e pour de nouvelles découvertes.",
#   'DEPART': 'Le Val-Saint-PÃ¨re',
#   'START_DEPART': 44,
#   'END_DEPART': 61,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Martin-de-ConnÃ©e',
#   'START_DEST': 96,
#   'END_DEST': 118,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de MartaizÃ© à Saint-DrÃ©zÃ©ry, j'ai été émerveillé(e) par la diversité.",
#   'DEPART': 'MartaizÃ©',
#   'START_DEPART': 17,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-DrÃ©zÃ©ry',
#   'START_DEST': 29,
#   'END_DEST': 43,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Einville-au-Jard, j'ai fait une pause à Calmels-et-le-Viala pour me ressourcer avant de continuer vers Pousthomy.",
#   'DEPART': 'Einville-au-Jard',
#   'START_DEPART': 21,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Calmels-et-le-Viala',
#   'START_DEST': 61,
#   'END_DEST': 79,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Saint-MÃ©dard, j'ai poursuivi mon périple jusqu'à Pont-Aven.",
#   'DEPART': 'Saint-MÃ©dard',
#   'START_DEPART': 20,
#   'END_DEPART': 32,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pont-Aven',
#   'START_DEST': 70,
#   'END_DEST': 78,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la route des artisans de HerrÃ© à Senneville-sur-FÃ©camp pour découvrir l'artisanat local et ses secrets.",
#   'DEPART': 'HerrÃ©',
#   'START_DEPART': 37,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Senneville-sur-FÃ©camp',
#   'START_DEST': 46,
#   'END_DEST': 67,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai fait étape à Avallon avant de me rendre à Autrey-lÃ¨s-Gray.",
#   'DEPART': 'Avallon',
#   'START_DEPART': 19,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Autrey-lÃ¨s-Gray',
#   'START_DEST': 48,
#   'END_DEST': 63,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par Saint-Laurent-Rochefort avant d'explorer SamÃ©on.",
#   'DEPART': 'Saint-Laurent-Rochefort',
#   'START_DEPART': 27,
#   'END_DEPART': 49,
#   'DEP': 'DEP',
#   'DESTINATION': 'SamÃ©on',
#   'START_DEST': 68,
#   'END_DEST': 74,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple a commencé à NÃ©rac où j'ai été accueilli(e) chaleureusement avant de me rendre à Poey-de-Lescar.",
#   'DEPART': 'NÃ©rac',
#   'START_DEPART': 26,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'Poey-de-Lescar',
#   'START_DEST': 95,
#   'END_DEST': 108,
#   'DEST': 'DEST'},
#  {'TEXT': "De Pousseaux à Domps, j'ai fait une escale enrichissante.",
#   'DEPART': 'Pousseaux',
#   'START_DEPART': 4,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Domps',
#   'START_DEST': 16,
#   'END_DEST': 20,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai entrepris mon voyage de Biard à Givet.",
#   'DEPART': 'Biard',
#   'START_DEPART': 30,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Givet',
#   'START_DEST': 38,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai commencé mon voyage à Illange où j'ai été plongé(e) dans une ambiance authentique avant de me rendre à Baldersheim pour explorer davantage.",
#   'DEPART': 'Illange',
#   'START_DEPART': 28,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Baldersheim',
#   'START_DEST': 109,
#   'END_DEST': 119,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Velone-Orneto, j'ai découvert les richesses cachées de Saint-Sauveur à travers des expériences authentiques.",
#   'DEPART': 'Velone-Orneto',
#   'START_DEPART': 15,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Sauveur',
#   'START_DEST': 70,
#   'END_DEST': 82,
#   'DEST': 'DEST'},
#  {'TEXT': 'On a visité Montagna-le-Reconduit et ensuite Ruffey-lÃ¨s-Beaune pour une escapade culturelle.',
#   'DEPART': 'Montagna-le-Reconduit',
#   'START_DEPART': 13,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ruffey-lÃ¨s-Beaune',
#   'START_DEST': 46,
#   'END_DEST': 63,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré les rues animées de Besse, j'ai savouré la tranquillité de Rodome.",
#   'DEPART': 'Besse',
#   'START_DEPART': 41,
#   'END_DEPART': 45,
#   'DEP': 'DEP',
#   'DESTINATION': 'Rodome',
#   'START_DEST': 80,
#   'END_DEST': 85,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la route des artisans de Juvigny-sur-Loison à Taulignan pour découvrir l'artisanat local et ses secrets.",
#   'DEPART': 'Juvigny-sur-Loison',
#   'START_DEPART': 37,
#   'END_DEPART': 54,
#   'DEP': 'DEP',
#   'DESTINATION': 'Taulignan',
#   'START_DEST': 58,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai entrepris mon voyage de Pellevoisin à ChalampÃ©.",
#   'DEPART': 'Pellevoisin',
#   'START_DEPART': 30,
#   'END_DEPART': 40,
#   'DEP': 'DEP',
#   'DESTINATION': 'ChalampÃ©',
#   'START_DEST': 44,
#   'END_DEST': 52,
#   'DEST': 'DEST'},
#  {'TEXT': "De Courteix jusqu'à Vassonville, mon trajet a été plein de surprises.",
#   'DEPART': 'Courteix',
#   'START_DEPART': 4,
#   'END_DEPART': 11,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vassonville',
#   'START_DEST': 21,
#   'END_DEST': 31,
#   'DEST': 'DEST'},
#  {'TEXT': "C'est de Flers-sur-Noye à Achy que j'ai tracé mon itinéraire.",
#   'DEPART': 'Flers-sur-Noye',
#   'START_DEPART': 10,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Achy',
#   'START_DEST': 27,
#   'END_DEST': 30,
#   'DEST': 'DEST'},
#  {'TEXT': "De Orsanco jusqu'à Omex, j'ai exploré les contrastes entre les villes animées et les villages pittoresques.",
#   'DEPART': 'Orsanco',
#   'START_DEPART': 4,
#   'END_DEPART': 10,
#   'DEP': 'DEP',
#   'DESTINATION': 'Omex',
#   'START_DEST': 20,
#   'END_DEST': 23,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire une escale à Guengat pour me perdre dans ses ruelles avant de reprendre ma route vers Vaux-Montreuil.",
#   'DEPART': 'Guengat',
#   'START_DEPART': 35,
#   'END_DEPART': 41,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vaux-Montreuil',
#   'START_DEST': 108,
#   'END_DEST': 121,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Thulay, je me suis dirigé(e) vers TrÃ©garantec.',
#   'DEPART': 'Thulay',
#   'START_DEPART': 15,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'TrÃ©garantec',
#   'START_DEST': 49,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par GÃ©nicourt, j'ai été subjugué(e) par l'authenticité avant de poursuivre vers La ChaussÃ©e pour un nouveau chapitre de mon voyage.",
#   'DEPART': 'GÃ©nicourt',
#   'START_DEPART': 16,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'La ChaussÃ©e',
#   'START_DEST': 93,
#   'END_DEST': 104,
#   'DEST': 'DEST'},
#  {'TEXT': "De Labastide à Saint-Pierre-de-Clairac, j'ai été captivé(e) par la beauté des lieux.",
#   'DEPART': 'Labastide',
#   'START_DEPART': 4,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Pierre-de-Clairac',
#   'START_DEST': 16,
#   'END_DEST': 38,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Riencourt-lÃ¨s-Cagnicourt à Gercy m'a offert une diversité incroyable.",
#   'DEPART': 'Riencourt-lÃ¨s-Cagnicourt',
#   'START_DEPART': 15,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'Gercy',
#   'START_DEST': 43,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Wattignies-la-Victoire, je me suis rendu(e) à Fumichon.',
#   'DEPART': 'Wattignies-la-Victoire',
#   'START_DEPART': 15,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Fumichon',
#   'START_DEST': 61,
#   'END_DEST': 68,
#   'DEST': 'DEST'},
#  {'TEXT': "En découvrant les coutumes authentiques de Foncegrive, j'ai poursuivi mon périple vers Maurrin pour de nouvelles découvertes.",
#   'DEPART': 'Foncegrive',
#   'START_DEPART': 44,
#   'END_DEPART': 53,
#   'DEP': 'DEP',
#   'DESTINATION': 'Maurrin',
#   'START_DEST': 88,
#   'END_DEST': 94,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité TrÃ©veneuc, j'ai ressenti le besoin de me rendre à Arras-sur-RhÃ´ne pour une retraite paisible en pleine nature.",
#   'DEPART': 'TrÃ©veneuc',
#   'START_DEPART': 20,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Arras-sur-RhÃ´ne',
#   'START_DEST': 71,
#   'END_DEST': 86,
#   'DEST': 'DEST'},
#  {'TEXT': 'Je suis passé(e) de Saint-Martial-de-Nabirat à ChÃ¢teau-Chinon (Campagne) pour découvrir de nouveaux horizons.',
#   'DEPART': 'Saint-Martial-de-Nabirat',
#   'START_DEPART': 21,
#   'END_DEPART': 44,
#   'DEP': 'DEP',
#   'DESTINATION': 'ChÃ¢teau-Chinon (Campagne)',
#   'START_DEST': 48,
#   'END_DEST': 73,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai exploré Toulouse avant de me diriger vers Paray-sous-Briailles.",
#   'DEPART': 'Toulouse',
#   'START_DEPART': 14,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Paray-sous-Briailles',
#   'START_DEST': 48,
#   'END_DEST': 67,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire un détour par Le PrÃ©-d'Auge pour un moment de détente avant de poursuivre vers Sainte-Christie pour de nouvelles découvertes.",
#   'DEPART': "Le PrÃ©-d'Auge",
#   'START_DEPART': 36,
#   'END_DEPART': 49,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-Christie',
#   'START_DEST': 102,
#   'END_DEST': 116,
#   'DEST': 'DEST'},
#  {'TEXT': 'Mon voyage de Berdoues à Artaise-le-Vivier était incroyable.',
#   'DEPART': 'Berdoues',
#   'START_DEPART': 15,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Artaise-le-Vivier',
#   'START_DEST': 26,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': "De CambounÃ¨s jusqu'à Les Ormes, mon trajet a été ponctué de découvertes surprenantes qui ont enrichi mon expérience.",
#   'DEPART': 'CambounÃ¨s',
#   'START_DEPART': 4,
#   'END_DEPART': 13,
#   'DEP': 'DEP',
#   'DESTINATION': 'Les Ormes',
#   'START_DEST': 23,
#   'END_DEST': 31,
#   'DEST': 'DEST'},
#  {'TEXT': "De Gayon à Le Mesnil-Villeman, j'ai été fasciné(e) par la diversité des paysages.",
#   'DEPART': 'Gayon',
#   'START_DEPART': 4,
#   'END_DEPART': 8,
#   'DEP': 'DEP',
#   'DESTINATION': 'Le Mesnil-Villeman',
#   'START_DEST': 12,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': "Je suis allé(e) de Binson-et-Orquigny jusqu'à Castineta pour explorer de nouveaux lieux.",
#   'DEPART': 'Binson-et-Orquigny',
#   'START_DEPART': 20,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Castineta',
#   'START_DEST': 47,
#   'END_DEST': 55,
#   'DEST': 'DEST'},
#  {'TEXT': 'Il est allé de MallÃ©on à Montlevicq pour ses vacances et y a trouvé une atmosphère de fête permanente.',
#   'DEPART': 'MallÃ©on',
#   'START_DEPART': 16,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montlevicq',
#   'START_DEST': 27,
#   'END_DEST': 36,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de Le Fraysse à Veauce, j'ai été surpris(e) par la richesse culturelle.",
#   'DEPART': 'Le Fraysse',
#   'START_DEPART': 17,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Veauce',
#   'START_DEST': 30,
#   'END_DEST': 35,
#   'DEST': 'DEST'},
#  {'TEXT': 'Ils ont voyagé de Cliron à Oullins pour affaires.',
#   'DEPART': 'Cliron',
#   'START_DEPART': 19,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Oullins',
#   'START_DEST': 28,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de Veney à Retschwiller, j'ai été surpris(e) par la richesse culturelle.",
#   'DEPART': 'Veney',
#   'START_DEPART': 17,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Retschwiller',
#   'START_DEST': 25,
#   'END_DEST': 36,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les vestiges anciens de Martignas-sur-Jalle, j'ai pris le chemin de Villers-Bouton pour une immersion dans la nature.",
#   'DEPART': 'Martignas-sur-Jalle',
#   'START_DEPART': 47,
#   'END_DEPART': 65,
#   'DEP': 'DEP',
#   'DESTINATION': 'Villers-Bouton',
#   'START_DEST': 91,
#   'END_DEST': 104,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai fait étape à Trentels avant de me rendre à Antezant-la-Chapelle.",
#   'DEPART': 'Trentels',
#   'START_DEPART': 19,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Antezant-la-Chapelle',
#   'START_DEST': 49,
#   'END_DEST': 68,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai commencé mon voyage à DÃ©gagnac où j'ai été plongé(e) dans une ambiance authentique avant de me rendre à Loupiac-de-la-RÃ©ole pour explorer davantage.",
#   'DEPART': 'DÃ©gagnac',
#   'START_DEPART': 28,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Loupiac-de-la-RÃ©ole',
#   'START_DEST': 111,
#   'END_DEST': 130,
#   'DEST': 'DEST'},
#  {'TEXT': 'Ils ont exploré Salagnon avant de se diriger vers PlÃ©nisette pour un séjour reposant au bord de la mer.',
#   'DEPART': 'Salagnon',
#   'START_DEPART': 17,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'PlÃ©nisette',
#   'START_DEST': 51,
#   'END_DEST': 61,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Saint-AndrÃ©-de-BuÃ¨ges, je me suis dirigé(e) vers Pierre-BÃ©nite.',
#   'DEPART': 'Saint-AndrÃ©-de-BuÃ¨ges',
#   'START_DEPART': 13,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pierre-BÃ©nite',
#   'START_DEST': 64,
#   'END_DEST': 77,
#   'DEST': 'DEST'},
#  {'TEXT': "De Alizay jusqu'à CrÃ©hange, j'ai suivi les sentiers des anciens habitants tout en découvrant des cultures contemporaines.",
#   'DEPART': 'Alizay',
#   'START_DEPART': 4,
#   'END_DEPART': 9,
#   'DEP': 'DEP',
#   'DESTINATION': 'CrÃ©hange',
#   'START_DEST': 19,
#   'END_DEST': 27,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Azy, j'ai été captivé(e) par la beauté naturelle avant de me rendre à Brinon-sur-Beuvron pour une aventure inattendue.",
#   'DEPART': 'Azy',
#   'START_DEPART': 16,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Brinon-sur-Beuvron',
#   'START_DEST': 86,
#   'END_DEST': 103,
#   'DEST': 'DEST'},
#  {'TEXT': "Après mon séjour à ReynÃ¨s, j'ai continué vers Mosson.",
#   'DEPART': 'ReynÃ¨s',
#   'START_DEPART': 20,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Mosson',
#   'START_DEST': 48,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir savouré l'ambiance vibrante de Buironfosse, j'ai pris le chemin de Saint-Germain-des-Angles pour une atmosphère plus paisible.",
#   'DEPART': 'Buironfosse',
#   'START_DEPART': 44,
#   'END_DEPART': 54,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Germain-des-Angles',
#   'START_DEST': 80,
#   'END_DEST': 103,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir quitté PÃ©rigny, je me suis dirigé(e) vers Annoisin-Chatelans pour une aventure en pleine nature.',
#   'DEPART': 'PÃ©rigny',
#   'START_DEPART': 20,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Annoisin-Chatelans',
#   'START_DEST': 56,
#   'END_DEST': 73,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la trace des explorateurs maritimes de Esclauzels à Subligny pour une aventure océanique.",
#   'DEPART': 'Esclauzels',
#   'START_DEPART': 51,
#   'END_DEPART': 60,
#   'DEP': 'DEP',
#   'DESTINATION': 'Subligny',
#   'START_DEST': 64,
#   'END_DEST': 71,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous avez exploré Tanneron avant de vous rendre à Belfays.',
#   'DEPART': 'Tanneron',
#   'START_DEPART': 19,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Belfays',
#   'START_DEST': 51,
#   'END_DEST': 57,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après mon passage à Wierre-au-Bois, je suis parti(e) pour Plats.',
#   'DEPART': 'Wierre-au-Bois',
#   'START_DEPART': 21,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Plats',
#   'START_DEST': 59,
#   'END_DEST': 63,
#   'DEST': 'DEST'},
#  {'TEXT': "De Jaulzy à Hautot-le-Vatois, j'ai été captivé(e) par la beauté des lieux.",
#   'DEPART': 'Jaulzy',
#   'START_DEPART': 4,
#   'END_DEPART': 9,
#   'DEP': 'DEP',
#   'DESTINATION': 'Hautot-le-Vatois',
#   'START_DEST': 13,
#   'END_DEST': 28,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir plongé dans l'histoire de MontmÃ©dy, j'ai poursuivi mon chemin jusqu'à Belrupt-en-Verdunois pour des aventures modernes.",
#   'DEPART': 'MontmÃ©dy',
#   'START_DEPART': 39,
#   'END_DEPART': 47,
#   'DEP': 'DEP',
#   'DESTINATION': 'Belrupt-en-Verdunois',
#   'START_DEST': 84,
#   'END_DEST': 103,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert Auffay, j'ai décidé de prolonger mon séjour et de visiter Valmeinier pour en apprendre davantage sur son histoire.",
#   'DEPART': 'Auffay',
#   'START_DEPART': 23,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Valmeinier',
#   'START_DEST': 81,
#   'END_DEST': 90,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage a débuté par une escale à Lunan où j'ai été séduit(e) par la culture locale avant de me diriger vers Abainville.",
#   'DEPART': 'Lunan',
#   'START_DEPART': 38,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Abainville',
#   'START_DEST': 113,
#   'END_DEST': 122,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon itinéraire m'a mené de Sainte-NÃ©omaye à Migron.",
#   'DEPART': 'Sainte-NÃ©omaye',
#   'START_DEPART': 28,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Migron',
#   'START_DEST': 46,
#   'END_DEST': 51,
#   'DEST': 'DEST'},
#  {'TEXT': 'Elles ont voyagé de Maux à Sainte-Sabine-sur-LongÃ¨ve pour une expérience enrichissante.',
#   'DEPART': 'Maux',
#   'START_DEPART': 21,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-Sabine-sur-LongÃ¨ve',
#   'START_DEST': 28,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir flâné dans les rues animées de Villiers-lÃ¨s-Aprey, j'ai pris la direction de Saint-Pierre-du-Fresne pour des expériences de plein air.",
#   'DEPART': 'Villiers-lÃ¨s-Aprey',
#   'START_DEPART': 44,
#   'END_DEPART': 62,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Pierre-du-Fresne',
#   'START_DEST': 91,
#   'END_DEST': 112,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la piste des aventuriers de Le Catelier à Saint-Lizier-du-PlantÃ© en explorant des sentiers hors des sentiers battus.",
#   'DEPART': 'Le Catelier',
#   'START_DEPART': 40,
#   'END_DEPART': 50,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Lizier-du-PlantÃ©',
#   'START_DEST': 54,
#   'END_DEST': 76,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi Montech comme prochaine destination après être passé(e) par Vicq-sur-Nahon.",
#   'DEPART': 'Montech',
#   'START_DEPART': 13,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vicq-sur-Nahon',
#   'START_DEST': 73,
#   'END_DEST': 86,
#   'DEST': 'DEST'},
#  {'TEXT': "À la suite de mon séjour à Oisy, j'ai voyagé jusqu'à Galgan.",
#   'DEPART': 'Oisy',
#   'START_DEPART': 28,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'Galgan',
#   'START_DEST': 54,
#   'END_DEST': 59,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les richesses artistiques de Tagolsheim, j'ai pris la direction de Jaulzy pour une immersion différente.",
#   'DEPART': 'Tagolsheim',
#   'START_DEPART': 52,
#   'END_DEPART': 61,
#   'DEP': 'DEP',
#   'DESTINATION': 'Jaulzy',
#   'START_DEST': 90,
#   'END_DEST': 95,
#   'DEST': 'DEST'},
#  {'TEXT': "De Thury-en-Valois à Remaugies, j'ai découvert de nouveaux horizons.",
#   'DEPART': 'Thury-en-Valois',
#   'START_DEPART': 4,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Remaugies',
#   'START_DEST': 22,
#   'END_DEST': 30,
#   'DEST': 'DEST'},
#  {'TEXT': "Après mon séjour à Les Touches, j'ai continué vers Chevincourt.",
#   'DEPART': 'Les Touches',
#   'START_DEPART': 20,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chevincourt',
#   'START_DEST': 52,
#   'END_DEST': 62,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire une halte à Martigny-le-Comte pour une expérience culturelle unique avant de rejoindre Bourgaltroff pour la suite de mon voyage.",
#   'DEPART': 'Martigny-le-Comte',
#   'START_DEPART': 34,
#   'END_DEPART': 50,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bourgaltroff',
#   'START_DEST': 109,
#   'END_DEST': 120,
#   'DEST': 'DEST'},
#  {'TEXT': "En quittant Barry-d'Islemade, je me suis dirigé(e) vers Saint-ClÃ©ment-les-Places.",
#   'DEPART': "Barry-d'Islemade",
#   'START_DEPART': 13,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-ClÃ©ment-les-Places',
#   'START_DEST': 57,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Saint-Bonnet-de-Four, je suis arrivé(e) à Festes-et-Saint-AndrÃ©.',
#   'DEPART': 'Saint-Bonnet-de-Four',
#   'START_DEPART': 15,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Festes-et-Saint-AndrÃ©',
#   'START_DEST': 57,
#   'END_DEST': 78,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Vivy pour aller à Sainte-Sabine, j'ai vécu des aventures incroyables.",
#   'DEPART': 'Vivy',
#   'START_DEPART': 15,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-Sabine',
#   'START_DEST': 33,
#   'END_DEST': 45,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Garrigues, je me suis dirigé(e) vers Soulce-Cernay.',
#   'DEPART': 'Garrigues',
#   'START_DEPART': 15,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Soulce-Cernay',
#   'START_DEST': 52,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Panassac, j'ai exploré les quartiers artistiques avant de me rendre à Le Guerno pour une immersion spirituelle.",
#   'DEPART': 'Panassac',
#   'START_DEPART': 16,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Le Guerno',
#   'START_DEST': 86,
#   'END_DEST': 94,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Hypercourt, je suis arrivé(e) à Laroquebrou.',
#   'DEPART': 'Hypercourt',
#   'START_DEPART': 15,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Laroquebrou',
#   'START_DEST': 47,
#   'END_DEST': 57,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les merveilles de Vaucelles et y avoir passé du temps, j'ai poursuivi mon voyage vers Saint-Nizier-d'Azergues pour une expérience totalement différente.",
#   'DEPART': 'Vaucelles',
#   'START_DEPART': 41,
#   'END_DEPART': 49,
#   'DEP': 'DEP',
#   'DESTINATION': "Saint-Nizier-d'Azergues",
#   'START_DEST': 109,
#   'END_DEST': 131,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire une escale à Cugnaux pour me perdre dans ses ruelles avant de reprendre ma route vers Contescourt.",
#   'DEPART': 'Cugnaux',
#   'START_DEPART': 35,
#   'END_DEPART': 41,
#   'DEP': 'DEP',
#   'DESTINATION': 'Contescourt',
#   'START_DEST': 108,
#   'END_DEST': 118,
#   'DEST': 'DEST'},
#  {'TEXT': 'Il est allé de Sains-lÃ¨s-Pernes à Malves-en-Minervois pour se ressourcer.',
#   'DEPART': 'Sains-lÃ¨s-Pernes',
#   'START_DEPART': 16,
#   'END_DEPART': 32,
#   'DEP': 'DEP',
#   'DESTINATION': 'Malves-en-Minervois',
#   'START_DEST': 36,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Gardonne, j'ai ressenti le besoin de me rendre à Montaut-les-CrÃ©neaux pour une retraite paisible en pleine nature.",
#   'DEPART': 'Gardonne',
#   'START_DEPART': 20,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montaut-les-CrÃ©neaux',
#   'START_DEST': 69,
#   'END_DEST': 89,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Vira, j'ai été captivé(e) par la beauté naturelle avant de me rendre à Colmar pour une aventure inattendue.",
#   'DEPART': 'Vira',
#   'START_DEPART': 16,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Colmar',
#   'START_DEST': 87,
#   'END_DEST': 92,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré ChacÃ©, j'ai été attiré(e) par Aumont-en-Halatte pour sa riche histoire.",
#   'DEPART': 'ChacÃ©',
#   'START_DEPART': 21,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Aumont-en-Halatte',
#   'START_DEST': 52,
#   'END_DEST': 68,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir savouré l'ambiance vibrante de Louversey, j'ai pris le chemin de Bagneux pour une atmosphère plus paisible.",
#   'DEPART': 'Louversey',
#   'START_DEPART': 44,
#   'END_DEPART': 52,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bagneux',
#   'START_DEST': 78,
#   'END_DEST': 84,
#   'DEST': 'DEST'},
#  {'TEXT': 'En visitant BrÃ©anÃ§on et ensuite Saint-Paul-lÃ¨s-Monestier, nous avons réalisé beaucoup de choses.',
#   'DEPART': 'BrÃ©anÃ§on',
#   'START_DEPART': 13,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Paul-lÃ¨s-Monestier',
#   'START_DEST': 35,
#   'END_DEST': 59,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de Bourgs sur Colagne à Brocourt-en-Argonne, j'ai été émerveillé(e) par la diversité.",
#   'DEPART': 'Bourgs sur Colagne',
#   'START_DEPART': 17,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Brocourt-en-Argonne',
#   'START_DEST': 38,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': "De Le Bar-sur-Loup à PouillÃ©-les-CÃ´teaux, j'ai exploré de nouveaux horizons.",
#   'DEPART': 'Le Bar-sur-Loup',
#   'START_DEPART': 4,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'PouillÃ©-les-CÃ´teaux',
#   'START_DEST': 22,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': "De Revin à Sonzay, j'ai fait une escale enrichissante.",
#   'DEPART': 'Revin',
#   'START_DEPART': 4,
#   'END_DEPART': 8,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sonzay',
#   'START_DEST': 12,
#   'END_DEST': 17,
#   'DEST': 'DEST'},
#  {'TEXT': "De Barret-de-Lioure à Nabringhen, j'ai fait une pause avant de repartir vers Offoy.",
#   'DEPART': 'Barret-de-Lioure',
#   'START_DEPART': 4,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Nabringhen',
#   'START_DEST': 23,
#   'END_DEST': 32,
#   'DEST': 'DEST'},
#  {'TEXT': "De Batz-sur-Mer à Les Pavillons-sous-Bois, j'ai apprécié chaque étape de mon voyage.",
#   'DEPART': 'Batz-sur-Mer',
#   'START_DEPART': 4,
#   'END_DEPART': 15,
#   'DEP': 'DEP',
#   'DESTINATION': 'Les Pavillons-sous-Bois',
#   'START_DEST': 19,
#   'END_DEST': 41,
#   'DEST': 'DEST'},
#  {'TEXT': "Lors de mon passage de Butry-sur-Oise à Saint-Sever-de-Rustan, j'ai été émerveillé(e).",
#   'DEPART': 'Butry-sur-Oise',
#   'START_DEPART': 24,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Sever-de-Rustan',
#   'START_DEST': 41,
#   'END_DEST': 61,
#   'DEST': 'DEST'},
#  {'TEXT': 'On a visité Houdreville et ensuite Plougrescant pour une expérience culinaire inégalée.',
#   'DEPART': 'Houdreville',
#   'START_DEPART': 13,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Plougrescant',
#   'START_DEST': 36,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les merveilles de Saint-FÃ©lix-Lauragais et y avoir passé du temps, j'ai poursuivi mon voyage vers Augerans pour une expérience totalement différente.",
#   'DEPART': 'Saint-FÃ©lix-Lauragais',
#   'START_DEPART': 41,
#   'END_DEPART': 62,
#   'DEP': 'DEP',
#   'DESTINATION': 'Augerans',
#   'START_DEST': 122,
#   'END_DEST': 129,
#   'DEST': 'DEST'},
#  {'TEXT': "Elle est partie de Canteloup pour découvrir Leucamp et s'y installer.",
#   'DEPART': 'Canteloup',
#   'START_DEPART': 20,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Leucamp',
#   'START_DEST': 45,
#   'END_DEST': 51,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai commencé mon périple à Missy-lÃ¨s-Pierrepont où j'ai été charmé(e) par l'authenticité avant de rejoindre Miraval-CabardÃ¨s pour une expérience inoubliable.",
#   'DEPART': 'Missy-lÃ¨s-Pierrepont',
#   'START_DEPART': 29,
#   'END_DEPART': 49,
#   'DEP': 'DEP',
#   'DESTINATION': 'Miraval-CabardÃ¨s',
#   'START_DEST': 111,
#   'END_DEST': 127,
#   'DEST': 'DEST'},
#  {'TEXT': "De Bourghelles à Eyrans, j'ai été captivé(e) par la beauté des lieux.",
#   'DEPART': 'Bourghelles',
#   'START_DEPART': 4,
#   'END_DEPART': 14,
#   'DEP': 'DEP',
#   'DESTINATION': 'Eyrans',
#   'START_DEST': 18,
#   'END_DEST': 23,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Langouet, j'ai poursuivi mon périple jusqu'à Perrier.",
#   'DEPART': 'Langouet',
#   'START_DEPART': 20,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Perrier',
#   'START_DEST': 65,
#   'END_DEST': 71,
#   'DEST': 'DEST'},
#  {'TEXT': "La Tieule m'a enchanté(e) avant d'atteindre Pontamafrey-Montpascal où j'ai été émerveillé(e) par son patrimoine historique.",
#   'DEPART': 'La Tieule',
#   'START_DEPART': 1,
#   'END_DEPART': 9,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pontamafrey-Montpascal',
#   'START_DEST': 45,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par MouazÃ© avant d'explorer Lanty.",
#   'DEPART': 'MouazÃ©',
#   'START_DEPART': 27,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Lanty',
#   'START_DEST': 52,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Bessey, j'ai continué ma route jusqu'à Richeville.",
#   'DEPART': 'Bessey',
#   'START_DEPART': 21,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Richeville',
#   'START_DEST': 60,
#   'END_DEST': 69,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Ens à Saint-Merd-la-Breuille pour un changement de paysage.',
# ...
#   'END_DEST': 83,
#   'DEST': 'DEST'},
#  {'TEXT': 'Lors de votre séjour de Forest-sur-Marque à Belmont-Bretenoux, vous avez vécu des moments uniques.',
#   'DEPART': 'Forest-sur-Marque',
#   'START_DEPART': 25,
#   'END_DEPART': 41,
#   'DEP': 'DEP',
#   'DESTINATION': 'Belmont-Bretenoux',
#   'START_DEST': 45,
#   'END_DEST': 61,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant de Bessan à Rauret, j'ai rencontré des personnes formidables.",
#   'DEPART': 'Bessan',
#   'START_DEPART': 15,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Rauret',
#   'START_DEST': 24,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': "Lors de mon passage de Ambleville à Saint-Gilles, j'ai été émerveillé(e).",
#   'DEPART': 'Ambleville',
#   'START_DEPART': 24,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Gilles',
#   'START_DEST': 37,
#   'END_DEST': 48,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant la modernité de Maxent, je suis allé(e) à Saint-Laurent-de-la-Cabrerisse pour me plonger dans la nature sauvage.',
#   'DEPART': 'Maxent',
#   'START_DEPART': 29,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Laurent-de-la-Cabrerisse',
#   'START_DEST': 55,
#   'END_DEST': 84,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de Ternant à Xivray-et-Marvoisin, j'ai été émerveillé(e) par la diversité.",
#   'DEPART': 'Ternant',
#   'START_DEPART': 17,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Xivray-et-Marvoisin',
#   'START_DEST': 27,
#   'END_DEST': 45,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de AmelÃ©court, je suis arrivé(e) à ArrembÃ©court.',
#   'DEPART': 'AmelÃ©court',
#   'START_DEPART': 15,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'ArrembÃ©court',
#   'START_DEST': 48,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': "De Ancourt à Agon-Coutainville, j'ai découvert de nouveaux horizons.",
#   'DEPART': 'Ancourt',
#   'START_DEPART': 4,
#   'END_DEPART': 10,
#   'DEP': 'DEP',
#   'DESTINATION': 'Agon-Coutainville',
#   'START_DEST': 14,
#   'END_DEST': 30,
#   'DEST': 'DEST'},
#  {'TEXT': "De Roissard jusqu'à Amance, j'ai parcouru des terres fertiles et des déserts arides pour une expérience contrastée.",
#   'DEPART': 'Roissard',
#   'START_DEPART': 4,
#   'END_DEPART': 11,
#   'DEP': 'DEP',
#   'DESTINATION': 'Amance',
#   'START_DEST': 21,
#   'END_DEST': 26,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple m'a mené de Reherrey à Yquebeuf.",
#   'DEPART': 'Reherrey',
#   'START_DEPART': 25,
#   'END_DEPART': 32,
#   'DEP': 'DEP',
#   'DESTINATION': 'Yquebeuf',
#   'START_DEST': 36,
#   'END_DEST': 43,
#   'DEST': 'DEST'},
#  {'TEXT': "En quittant GÃ©e-RiviÃ¨re, j'ai été frappé(e) par la diversité culturelle avant de me diriger vers Aussac pour une immersion différente.",
#   'DEPART': 'GÃ©e-RiviÃ¨re',
#   'START_DEPART': 13,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Aussac',
#   'START_DEST': 100,
#   'END_DEST': 105,
#   'DEST': 'DEST'},
#  {'TEXT': "De Argeliers à Belin-BÃ©liet, j'ai parcouru un long chemin.",
#   'DEPART': 'Argeliers',
#   'START_DEPART': 4,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Belin-BÃ©liet',
#   'START_DEST': 16,
#   'END_DEST': 28,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de m'éloigner de la foule en passant par Bouqueval pour découvrir la quiétude de Saint-Bernard.",
#   'DEPART': 'Bouqueval',
#   'START_DEPART': 54,
#   'END_DEPART': 62,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Bernard',
#   'START_DEST': 94,
#   'END_DEST': 106,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert Arquettes-en-Val, j'ai décidé de me rendre à La Malmaison.",
#   'DEPART': 'Arquettes-en-Val',
#   'START_DEPART': 23,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'La Malmaison',
#   'START_DEST': 68,
#   'END_DEST': 79,
#   'DEST': 'DEST'},
#  {'TEXT': "En explorant Raissac-sur-Lampy, j'ai été ébloui(e) par la richesse architecturale avant de me diriger vers Entre-deux-Monts.",
#   'DEPART': 'Raissac-sur-Lampy',
#   'START_DEPART': 14,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Entre-deux-Monts',
#   'START_DEST': 108,
#   'END_DEST': 123,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi Brusvily comme prochaine destination après être passé(e) par Couville.",
#   'DEPART': 'Brusvily',
#   'START_DEPART': 13,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Couville',
#   'START_DEST': 74,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de Soubise à Beaurain, j'ai été émerveillé(e) par la diversité.",
#   'DEPART': 'Soubise',
#   'START_DEPART': 17,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Beaurain',
#   'START_DEST': 27,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': "Vinay m'a enchanté(e) avant d'atteindre Blacourt où j'ai été émerveillé(e) par son patrimoine historique.",
#   'DEPART': 'Vinay',
#   'START_DEPART': 1,
#   'END_DEPART': 5,
#   'DEP': 'DEP',
#   'DESTINATION': 'Blacourt',
#   'START_DEST': 41,
#   'END_DEST': 48,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré les quartiers colorés de Contres, j'ai pris la route vers La VespiÃ¨re-Friardel pour une plongée dans la diversité culturelle.",
#   'DEPART': 'Contres',
#   'START_DEPART': 46,
#   'END_DEPART': 52,
#   'DEP': 'DEP',
#   'DESTINATION': 'La VespiÃ¨re-Friardel',
#   'START_DEST': 79,
#   'END_DEST': 99,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté Le Tremblay-Omonville pour me diriger vers Jau-Dignac-et-Loirac.",
#   'DEPART': 'Le Tremblay-Omonville',
#   'START_DEPART': 13,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Jau-Dignac-et-Loirac',
#   'START_DEST': 56,
#   'END_DEST': 75,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir quitté Le Soler, je me suis dirigé(e) vers Scata.',
#   'DEPART': 'Le Soler',
#   'START_DEPART': 20,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Scata',
#   'START_DEST': 56,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': 'Je suis passé(e) de Ã\x89cuvilly à Bougy pour une expérience enrichissante.',
#   'DEPART': 'Ã\x89cuvilly',
#   'START_DEPART': 21,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bougy',
#   'START_DEST': 33,
#   'END_DEST': 37,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi Pouilly comme prochaine destination après être passé(e) par Houeydets où j'ai découvert des traditions ancestrales.",
#   'DEPART': 'Pouilly',
#   'START_DEPART': 13,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Houeydets',
#   'START_DEST': 73,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Pont-l'Ã\x89vÃªque, j'ai finalement atteint Saint-Alban-d'HurtiÃ¨res.",
#   'DEPART': "Pont-l'Ã\x89vÃªque",
#   'START_DEPART': 16,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': "Saint-Alban-d'HurtiÃ¨res",
#   'START_DEST': 57,
#   'END_DEST': 80,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage a débuté par une escale à Noreuil où j'ai été séduit(e) par la culture locale avant de me diriger vers Montpensier.",
#   'DEPART': 'Noreuil',
#   'START_DEPART': 38,
#   'END_DEPART': 44,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montpensier',
#   'START_DEST': 115,
#   'END_DEST': 125,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par La Faurie avant d'explorer Daubeuf-prÃ¨s-Vatteville.",
#   'DEPART': 'La Faurie',
#   'START_DEPART': 27,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Daubeuf-prÃ¨s-Vatteville',
#   'START_DEST': 54,
#   'END_DEST': 77,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré Saint-Christoly-MÃ©doc, je me suis dirigé(e) vers Saint-Germain-de-Coulamer pour une immersion totale dans une nouvelle culture.',
#   'DEPART': 'Saint-Christoly-MÃ©doc',
#   'START_DEPART': 21,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Germain-de-Coulamer',
#   'START_DEST': 71,
#   'END_DEST': 95,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai vogué des plages de sable fin de Secourt vers les sommets majestueux de Bioussac.",
#   'DEPART': 'Secourt',
#   'START_DEPART': 39,
#   'END_DEPART': 45,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bioussac',
#   'START_DEST': 78,
#   'END_DEST': 85,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant LandÃ©an, je suis allé(e) à Saint-Hilaire-Saint-Mesmin pour découvrir de nouveaux paysages.',
#   'DEPART': 'LandÃ©an',
#   'START_DEPART': 13,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Hilaire-Saint-Mesmin',
#   'START_DEST': 41,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "De Murs-et-GÃ©lignieux à Marcilly-en-Bassigny, j'ai fait une escale enrichissante.",
#   'DEPART': 'Murs-et-GÃ©lignieux',
#   'START_DEPART': 4,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Marcilly-en-Bassigny',
#   'START_DEST': 26,
#   'END_DEST': 45,
#   'DEST': 'DEST'},
#  {'TEXT': "De Le Sappey-en-Chartreuse à Sebourg, chaque étape a été une source d'émerveillement.",
#   'DEPART': 'Le Sappey-en-Chartreuse',
#   'START_DEPART': 4,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sebourg',
#   'START_DEST': 30,
#   'END_DEST': 36,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré les rues animées de Saint-Julien-le-Roux, je me suis dirigé(e) vers Villers-lÃ¨s-Nancy pour un peu de tranquillité.',
#   'DEPART': 'Saint-Julien-le-Roux',
#   'START_DEPART': 41,
#   'END_DEPART': 60,
#   'DEP': 'DEP',
#   'DESTINATION': 'Villers-lÃ¨s-Nancy',
#   'START_DEST': 89,
#   'END_DEST': 106,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Breuil-le-Vert, j'ai fait une halte à Saint-Jean-de-Bonneval pour m'imprégner de son histoire avant de poursuivre vers Gironde-sur-Dropt.",
#   'DEPART': 'Breuil-le-Vert',
#   'START_DEPART': 21,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Jean-de-Bonneval',
#   'START_DEST': 59,
#   'END_DEST': 80,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai entrepris mon voyage de BeaucouzÃ© à BuxiÃ¨res-les-Mines.",
#   'DEPART': 'BeaucouzÃ©',
#   'START_DEPART': 30,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'BuxiÃ¨res-les-Mines',
#   'START_DEST': 43,
#   'END_DEST': 61,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant de Brion à Marols, j'ai rencontré des guides locaux passionnés qui m'ont fait découvrir des endroits secrets.",
#   'DEPART': 'Brion',
#   'START_DEPART': 15,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Marols',
#   'START_DEST': 23,
#   'END_DEST': 28,
#   'DEST': 'DEST'},
#  {'TEXT': 'Parti(e) de Soubrebost et arrivé(e) à Castelnaud-de-Gratecambe, un voyage inoubliable.',
#   'DEPART': 'Soubrebost',
#   'START_DEPART': 13,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Castelnaud-de-Gratecambe',
#   'START_DEST': 39,
#   'END_DEST': 62,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir admiré Missillac, j'ai entrepris d'explorer ThenneliÃ¨res.",
#   'DEPART': 'Missillac',
#   'START_DEPART': 20,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'ThenneliÃ¨res',
#   'START_DEST': 57,
#   'END_DEST': 69,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par Saint-AndrÃ© avant d'explorer Saint-Jean-de-Moirans.",
#   'DEPART': 'Saint-AndrÃ©',
#   'START_DEPART': 27,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Jean-de-Moirans',
#   'START_DEST': 57,
#   'END_DEST': 77,
#   'DEST': 'DEST'},
#  {'TEXT': "Ma visite à SÃ©ranon m'a inspiré(e) à explorer les trésors cachés de La Fontelaye.",
#   'DEPART': 'SÃ©ranon',
#   'START_DEPART': 13,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'La Fontelaye',
#   'START_DEST': 70,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Saint-Germain-de-Salles, je me suis dirigé(e) vers Maulan pour de nouvelles découvertes.',
#   'DEPART': 'Saint-Germain-de-Salles',
#   'START_DEPART': 13,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Maulan',
#   'START_DEST': 64,
#   'END_DEST': 69,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Monze, j'ai finalement atteint Gouy-Servins.",
#   'DEPART': 'Monze',
#   'START_DEPART': 16,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Gouy-Servins',
#   'START_DEST': 47,
#   'END_DEST': 58,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Beauclair pour aller à Nannay, j'ai vécu des rencontres humaines uniques et enrichissantes.",
#   'DEPART': 'Beauclair',
#   'START_DEPART': 15,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Nannay',
#   'START_DEST': 38,
#   'END_DEST': 43,
#   'DEST': 'DEST'},
#  {'TEXT': "Après mon passage à Sanssac-l'Ã\x89glise, je suis parti(e) pour Avril.",
#   'DEPART': "Sanssac-l'Ã\x89glise",
#   'START_DEPART': 21,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Avril',
#   'START_DEST': 62,
#   'END_DEST': 66,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Labergement-lÃ¨s-Seurre, j'ai suivi le chemin vers Rozoy-Bellevalle pour découvrir les merveilles naturelles cachées.",
#   'DEPART': 'Labergement-lÃ¨s-Seurre',
#   'START_DEPART': 15,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Rozoy-Bellevalle',
#   'START_DEST': 66,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "De LauriÃ¨re à Merry-Sec, j'ai suivi les traces de l'histoire et de la culture locale.",
#   'DEPART': 'LauriÃ¨re',
#   'START_DEPART': 4,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Merry-Sec',
#   'START_DEST': 16,
#   'END_DEST': 24,
#   'DEST': 'DEST'},
#  {'TEXT': "De Griselles à Fonches-Fonchette, j'ai suivi les traces de l'histoire et de la culture locale.",
#   'DEPART': 'Griselles',
#   'START_DEPART': 4,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Fonches-Fonchette',
#   'START_DEST': 16,
#   'END_DEST': 32,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple m'a conduit(e) de Sarrazac à Crochte où j'ai eu l'occasion de m'immerger dans l'histoire fascinante de ces lieux.",
#   'DEPART': 'Sarrazac',
#   'START_DEPART': 31,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'Crochte',
#   'START_DEST': 42,
#   'END_DEST': 48,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant de Chalencon à Le Merzer, j'ai rencontré des guides locaux passionnés qui m'ont fait découvrir des endroits secrets.",
#   'DEPART': 'Chalencon',
#   'START_DEPART': 15,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Le Merzer',
#   'START_DEST': 27,
#   'END_DEST': 35,
#   'DEST': 'DEST'},
#  {'TEXT': "En quittant Torchamp, j'ai été charmé(e) par la simplicité de Malrevers avant de poursuivre vers de nouveaux horizons à MÃ©nil.",
#   'DEPART': 'Torchamp',
#   'START_DEPART': 13,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Malrevers',
#   'START_DEST': 63,
#   'END_DEST': 71,
#   'DEST': 'DEST'},
#  {'TEXT': "De Tanzac à FÃ©cocourt, j'ai fait une escale enrichissante.",
#   'DEPART': 'Tanzac',
#   'START_DEPART': 4,
#   'END_DEPART': 9,
#   'DEP': 'DEP',
#   'DESTINATION': 'FÃ©cocourt',
#   'START_DEST': 13,
#   'END_DEST': 22,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert Coolus, j'ai décidé de me rendre à Grisy-sur-Seine pour en voir plus.",
#   'DEPART': 'Coolus',
#   'START_DEPART': 23,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Grisy-sur-Seine',
#   'START_DEST': 58,
#   'END_DEST': 72,
#   'DEST': 'DEST'},
#  {'TEXT': "De Marizy-Sainte-GeneviÃ¨ve, j'ai fait un saut à Chambly pour une expérience enrichissante avant de revenir à mon itinéraire initial vers Marolles-lÃ¨s-Bailly.",
#   'DEPART': 'Marizy-Sainte-GeneviÃ¨ve',
#   'START_DEPART': 4,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chambly',
#   'START_DEST': 50,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': "Lors de mon voyage, de Boulogne-sur-Mer à BÃ©gard, j'ai découvert de nouveaux horizons.",
#   'DEPART': 'Boulogne-sur-Mer',
#   'START_DEPART': 24,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'BÃ©gard',
#   'START_DEST': 43,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Lieuran-lÃ¨s-BÃ©ziers à La GenÃªte pour vos vacances.',
#   'DEPART': 'Lieuran-lÃ¨s-BÃ©ziers',
#   'START_DEPART': 22,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'La GenÃªte',
#   'START_DEST': 46,
#   'END_DEST': 55,
#   'DEST': 'DEST'},
#  {'TEXT': "En explorant Herbeuville, j'ai été ébloui(e) par la richesse architecturale avant de me diriger vers Jons.",
#   'DEPART': 'Herbeuville',
#   'START_DEPART': 14,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Jons',
#   'START_DEST': 102,
#   'END_DEST': 105,
#   'DEST': 'DEST'},
#  {'TEXT': "De BarÃ©sia-sur-l'Ain à Canet, j'ai découvert de nouveaux horizons.",
#   'DEPART': "BarÃ©sia-sur-l'Ain",
#   'START_DEPART': 4,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Canet',
#   'START_DEST': 25,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir quitté Poligny, je me suis dirigé(e) vers Feins.',
#   'DEPART': 'Poligny',
#   'START_DEPART': 20,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Feins',
#   'START_DEST': 55,
#   'END_DEST': 59,
#   'DEST': 'DEST'}]
