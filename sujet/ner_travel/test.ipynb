# %%
import pandas as pd
import tarfile
import os

# %%
tar = tarfile.open('assets/villes.tar.gz', 'r:gz')
tar.extractall(path=('assets'))
tar.close()

# %%
import random

# %%
from pandas import read_csv

# %%
villes = read_csv('assets/csv/cities.csv', encoding = "ISO-8859-1", usecols=['name'])

# %%
output = "assets/travel_training.csv"

# %%
villes
# Out:
#                            name
# 0      L'Abergement-ClÃ©menciat
# 1         L'Abergement-de-Varey
# 2            AmbÃ©rieu-en-Bugey
# 3          AmbÃ©rieux-en-Dombes
# 4                      AmblÃ©on
# ...                         ...
# 35848                     Touho
# 35849                       Voh
# 35850                     YatÃ©
# 35851                   Kouaoua
# 35852        Ãle de Clipperton
#
# [35853 rows x 1 columns]

# %%
patterns = [
        "Après avoir exploré les rues animées de {}, je me suis dirigé(e) vers {} pour un peu de tranquillité.",
        "De {} à {}, j'ai suivi les traces de l'histoire et de la culture locale.",
        "J'ai sillonné les sentiers verdoyants de {} avant de me retrouver à {} pour une immersion urbaine.",
        "Après avoir goûté aux délices culinaires de {}, j'ai cherché à découvrir les spécialités de {}.",
        "En passant par {}, j'ai été ébloui(e) par la diversité architecturale avant de me rendre à {} pour explorer les traditions locales.",
        "De {} jusqu'à {}, j'ai suivi le cours d'un fleuve et découvert des paysages à couper le souffle.",
        "Après avoir plongé dans l'histoire de {}, j'ai poursuivi mon chemin jusqu'à {} pour des aventures modernes.",
        "J'ai vogué des plages de sable fin de {} vers les sommets majestueux de {}.",
        "Après avoir arpenté les ruelles étroites de {}, j'ai pris la direction de {} pour une vue panoramique.",
        "En partant de {}, j'ai traversé des vallées verdoyantes pour arriver à {} et ses montagnes escarpées.",
        "De {} à {}, j'ai été subjugué(e) par la fusion parfaite entre tradition et modernité.",
        "Après avoir exploré les quartiers animés de {}, je me suis ressourcé(e) dans la quiétude de {}.",
        "J'ai suivi la route des vins de {} à {}, découvrant ainsi les saveurs uniques de chaque région.",
        "En passant par {}, j'ai été émerveillé(e) par l'art avant-gardiste avant de rejoindre {} pour une expérience culturelle différente.",
        "Après avoir découvert les vestiges anciens de {}, j'ai pris le chemin de {} pour une immersion dans la nature.",
        "De {} jusqu'à {}, j'ai exploré les contrastes entre les villes animées et les villages pittoresques.",
        "J'ai suivi le cours d'une rivière de {} à {} en découvrant des paysages variés et enchanteurs.",
        "En partant de {}, j'ai été attiré(e) par la vie nocturne effervescente de {}.",
        "Après avoir visité les musées de {}, j'ai décidé de m'aventurer vers {} pour une expérience artistique différente.",
        "De {} à {}, j'ai parcouru des sentiers insolites pour découvrir des trésors cachés.",
        "J'ai plongé dans les eaux cristallines de {} avant de gravir les sommets de {} pour une vue imprenable.",
        "Après avoir flâné dans les jardins botaniques de {}, j'ai pris la direction de {} pour explorer des parcs nationaux.",
        "En passant par {}, j'ai exploré les marchés locaux avant de me rendre à {} pour une immersion dans la cuisine régionale.",
        "De {} jusqu'à {}, j'ai suivi les chemins de traverse pour découvrir des panoramas spectaculaires.",
        "J'ai suivi la piste des aventuriers de {} à {} en explorant des sentiers hors des sentiers battus.",
        "Après avoir exploré les quartiers colorés de {}, j'ai pris la route vers {} pour une plongée dans la diversité culturelle.",
        "De {} à {}, j'ai suivi les traces des explorateurs anciens tout en explorant des attractions modernes.",
        "En partant de {}, j'ai découvert les richesses cachées de {} à travers des expériences authentiques.",
        "Après avoir admiré les édifices historiques de {}, j'ai continué vers {} pour explorer des sites naturels.",
        "De {} jusqu'à {}, j'ai parcouru des terres fertiles et des déserts arides pour une expérience contrastée.",
        "J'ai suivi la route des artisans de {} à {} pour découvrir l'artisanat local et ses secrets.",
        "En passant par {}, j'ai exploré les quartiers artistiques avant de me rendre à {} pour une immersion spirituelle.",
        "De {} à {}, j'ai été séduit(e) par la diversité des paysages et des traditions locales.",
        "J'ai suivi la trace des explorateurs maritimes de {} à {} pour une aventure océanique.",
        "Après avoir exploré les marchés animés de {}, j'ai suivi la piste vers {} pour une expérience gastronomique inoubliable.",
        "En partant de {}, j'ai suivi le chemin vers {} pour découvrir les merveilles naturelles cachées.",
        "De {} jusqu'à {}, j'ai suivi les sentiers des anciens habitants tout en découvrant des cultures contemporaines.",
        "Après avoir flâné dans les rues animées de {}, j'ai pris la direction de {} pour des expériences de plein air.",
        "J'ai suivi la route des explorateurs culinaires de {} à {} en dégustant des mets locaux authentiques.",
        "En passant par {}, j'ai été séduit(e) par les festivals culturels avant de me rendre à {} pour des escapades rurales.",
        "De {} à {}, j'ai suivi les chemins des conteurs locaux tout en explorant des sites historiques.",
        "J'ai exploré les quartiers cosmopolites de {} avant de rejoindre {} pour une immersion dans la nature sauvage.",
        "Après avoir exploré les rues animées de {}, j'ai savouré la tranquillité de {}.",
        "En quittant {}, je me suis émerveillé(e) devant la majesté de {}.",
        "Mon périple a commencé à {} où j'ai été accueilli(e) chaleureusement avant de me rendre à {}.",
        "J'ai découvert une culture fascinante à {} avant de m'immerger dans celle de {}.",
        "Après avoir contemplé les paysages envoûtants de {}, j'ai pris la route vers {}.",
        "En visitant {}, j'ai été inspiré(e) par l'histoire avant de découvrir les merveilles de {}.",
        "J'ai décidé de faire un détour par {} pour apprécier les délices culinaires avant de continuer vers {}.",
        "De {}, j'ai fait un saut à {} pour une expérience enrichissante avant de revenir à mon itinéraire initial vers {}.",
        "Après avoir rencontré des habitants sympathiques à {}, j'ai poursuivi mon chemin vers {} pour explorer davantage.",
        "Mon voyage a débuté par une escale à {} où j'ai été séduit(e) par la culture locale avant de me diriger vers {}.",
        "En quittant {}, j'ai été captivé(e) par la diversité culturelle de {}.",
        "Après avoir profité des paysages spectaculaires de {}, j'ai repris la route vers {}.",
        "J'ai choisi de m'éloigner de la foule en passant par {} pour découvrir la quiétude de {}.",
        "En explorant {}, j'ai été ébloui(e) par la richesse architecturale avant de me diriger vers {}.",
        "Après avoir découvert les traditions uniques de {}, j'ai continué vers {} pour vivre de nouvelles expériences.",
        "En quittant la modernité de {}, je suis allé(e) à {} pour me plonger dans la nature sauvage.",
        "J'ai été attiré(e) par les festivités animées de {} avant de me rendre à {} pour un contraste apaisant.",
        "Après avoir arpenté les ruelles de {} et exploré ses secrets, j'ai pris la direction de {} pour une atmosphère différente.",
        "En passant par {}, j'ai été subjugué(e) par l'authenticité avant de poursuivre vers {} pour un nouveau chapitre de mon voyage.",
        "J'ai commencé mon aventure à {} en me laissant surprendre par sa diversité avant de partir à la découverte de {}.",
        "Après avoir profité de la convivialité de {}, j'ai repris ma route vers {} pour découvrir de nouvelles perspectives.",
        "En quittant {}, j'ai été fasciné(e) par l'héritage historique avant de m'immerger dans la modernité de {}.",
        "J'ai décidé de faire une halte à {} pour une expérience culturelle unique avant de rejoindre {} pour la suite de mon voyage.",
        "Après avoir exploré les trésors cachés de {}, j'ai décidé de visiter {} pour élargir mes horizons.",
        "En découvrant les coutumes authentiques de {}, j'ai poursuivi mon périple vers {} pour de nouvelles découvertes.",
        "J'ai été séduit(e) par la tranquillité de {} avant de repartir pour {} où l'aventure m'attendait.",
        "Après avoir exploré {}, j'ai fait une pause à {} pour me ressourcer avant de continuer vers {}.",
        "En quittant {}, j'ai été charmé(e) par la simplicité de {} avant de poursuivre vers de nouveaux horizons à {}.",
        "J'ai commencé mon voyage à {} où j'ai été plongé(e) dans une ambiance authentique avant de me rendre à {} pour explorer davantage.",
        "Après avoir découvert les richesses artistiques de {}, j'ai pris la direction de {} pour une immersion différente.",
        "En passant par {}, j'ai été surpris(e) par la diversité culturelle avant de me diriger vers {} pour un tout autre paysage.",
        "J'ai décidé de faire une escale à {} pour me perdre dans ses ruelles avant de reprendre ma route vers {}.",
        "Après avoir savouré l'ambiance vibrante de {}, j'ai pris le chemin de {} pour une atmosphère plus paisible.",
        "En quittant {}, j'ai été ému(e) par la spiritualité avant de me rendre à {} pour une expérience spirituelle différente.",
        "J'ai été inspiré(e) par l'authenticité de {} avant de continuer mon voyage vers {} pour une aventure hors du commun.",
        "Après avoir exploré {}, j'ai choisi de m'évader à {} pour un changement radical d'atmosphère.",
        "En découvrant {}, j'ai été immergé(e) dans la culture locale avant de me rendre à {} pour explorer de nouvelles traditions.",
        "J'ai décidé de faire un détour par {} pour un moment de détente avant de poursuivre vers {} pour de nouvelles découvertes.",
        "Après avoir apprécié la gastronomie de {}, j'ai repris ma route vers {} pour une exploration plus approfondie.",
        "En quittant {}, j'ai été frappé(e) par la diversité culturelle avant de me diriger vers {} pour une immersion différente.",
        "J'ai commencé mon périple à {} où j'ai été charmé(e) par l'authenticité avant de rejoindre {} pour une expérience inoubliable.",
        "Après avoir exploré {}, j'ai fait une halte à {} pour m'imprégner de son histoire avant de poursuivre vers {}.",
        "En passant par {}, j'ai été captivé(e) par la beauté naturelle avant de me rendre à {} pour une aventure inattendue.",
        "Après avoir exploré {}, je me suis dirigé(e) vers {} pour une immersion totale dans une nouvelle culture.",
        "En partant de {}, j'ai suivi un chemin sinueux pour finalement arriver à {} et être ébloui(e) par sa beauté naturelle.",
        "Mon périple m'a conduit(e) de {} à {} où j'ai eu l'occasion de m'immerger dans l'histoire fascinante de ces lieux.",
        "Après une halte à {}, j'ai continué mon voyage jusqu'à {} pour vivre une aventure inattendue.",
        "De {} jusqu'à {}, chaque étape de mon itinéraire a été marquée par des rencontres inspirantes.",
        "En explorant {}, j'ai été séduit(e) par son architecture avant-gardiste avant de me rendre à {} pour une expérience plus traditionnelle.",
        "J'ai quitté {} pour me rendre à {} où j'ai été accueilli(e) chaleureusement par les habitants.",
        "Après avoir découvert {}, j'ai décidé de prolonger mon séjour et de visiter {} pour en apprendre davantage sur son histoire.",
        "En passant par {}, j'ai été transporté(e) dans un monde de saveurs culinaires avant de continuer mon périple jusqu'à {}.",
        "Mon voyage de {} à {} m'a permis de constater la diversité incroyable des paysages rencontrés en chemin.",
        "Après avoir visité {}, j'ai ressenti le besoin de me rendre à {} pour une retraite paisible en pleine nature.",
        "J'ai choisi {} comme prochaine destination après être passé(e) par {} où j'ai découvert des traditions ancestrales.",
        "Entre {} et {}, j'ai été émerveillé(e) par la richesse artistique et culturelle de ces lieux.",
        "Après avoir contemplé {}, j'ai entrepris de visiter {} pour explorer ses merveilles cachées.",
        "En découvrant {}, j'ai été attiré(e) par {} et sa réputation de ville animée et cosmopolite.",
        "Après {} est venu {} dans mon itinéraire, m'offrant une transition parfaite entre deux expériences uniques.",
        "J'ai exploré {} avant de me diriger vers {} pour une immersion dans des paysages à couper le souffle.",
        "Ma route m'a conduit(e) de {} à {} où j'ai eu la chance de participer à des festivités locales.",
        "Après mon séjour à {}, j'ai continué vers {} pour une expérience gastronomique exceptionnelle.",
        "J'ai voyagé de {} à {} pour découvrir de nouvelles coutumes et traditions fascinantes.",
        "De {} jusqu'à {}, mon trajet a été ponctué de découvertes surprenantes qui ont enrichi mon expérience.",
        "En partant de {} pour aller à {}, j'ai vécu des rencontres humaines uniques et enrichissantes.",
        "J'ai exploré {} avant de découvrir {} où j'ai été plongé(e) dans une atmosphère vibrante et dynamique.",
        "De {} à {}, j'ai fait une escale enrichissante où j'ai pu participer à des activités traditionnelles.",
        "Après mon passage à {}, je suis parti(e) pour {} pour une expérience de détente et de bien-être.",
        "J'ai continué mon voyage de {} à {} où j'ai été impressionné(e) par la modernité et l'effervescence de la ville.",
        "{} m'a enchanté(e) avant d'atteindre {} où j'ai été émerveillé(e) par son patrimoine historique.",
        "Après avoir exploré {}, je suis parti(e) à {} pour un séjour de ressourcement au cœur de la nature.",
        "En passant de {} à {}, j'ai rencontré des guides locaux passionnés qui m'ont fait découvrir des endroits secrets.",
        "Lors de mon voyage, de {} à {}, j'ai découvert de nouveaux horizons qui ont élargi ma perception du monde.",
        "Parti(e) de {} et arrivé(e) à {}, un voyage parsemé de découvertes culturelles et humaines.",
        "En partant de {}, je me suis dirigé(e) vers {} pour une immersion dans des traditions ancestrales.",
        "C'est de {} à {} que j'ai tracé mon itinéraire, m'offrant une diversité d'expériences inoubliables.",
        "Après avoir quitté {}, je me suis dirigé(e) vers {} pour une aventure en pleine nature.",
        "J'ai choisi de passer par {} avant d'explorer {} et d'y découvrir une scène artistique bouillonnante.",
        "En visitant {} et ensuite {}, j'ai appris à connaître les différentes facettes d'un même pays.",
        "Ils ont exploré {} avant de se diriger vers {} pour un séjour reposant au bord de la mer.",
        "Elles ont parcouru un long chemin de {} à {} où elles ont découvert une hospitalité exceptionnelle.",
        "Il est allé de {} à {} pour ses vacances et y a trouvé une atmosphère de fête permanente.",
        "Elle est partie de {} pour découvrir {} et y a rencontré une communauté accueillante et chaleureuse.",
        "On a visité {} et ensuite {} pour une expérience culinaire inégalée.",
        "Vous êtes allé(e) de {} à {} pour une aventure sportive et de plein air.",
        "Après avoir exploré {}, j'ai été attiré(e) par {} pour sa riche histoire.",
        "En débutant mon voyage à {}, j'ai été immédiatement séduit(e) par l'atmosphère vibrante de la ville avant d'arriver à {}.",
        "De {}, j'ai entrepris un périple jusqu'à {} pour découvrir sa culture unique et ses traditions anciennes.",
        "Après un séjour enrichissant à {}, j'ai pris la décision de me rendre à {} pour son paysage époustouflant.",
        "Ma visite à {} m'a inspiré(e) à explorer les trésors cachés de {}.",
        "En passant par {}, j'ai été émerveillé(e) par la diversité des expériences que cette région offre avant de poursuivre vers {}.",
        "Après avoir découvert les merveilles de {} et y avoir passé du temps, j'ai poursuivi mon voyage vers {} pour une expérience totalement différente.",
        "De {} à {}, chaque étape était une aventure unique où j'ai rencontré des gens formidables et découvert des traditions fascinantes.",
        "J'ai quitté ma ville natale de {} pour me plonger dans l'effervescence de {} et sa vie nocturne animée.",
        "Après avoir contemplé la beauté naturelle de {}, j'ai choisi de me rendre à {} pour explorer ses monuments historiques.",
        "J'ai entrepris mon voyage de {} à {}.",
        "{} m'a enchanté(e) avant d'atteindre {}.",
        "J'ai choisi de passer par {} avant d'explorer {}.",
        "Je suis allé(e) de {} à {}.",
        "J'ai visité {} avant de découvrir {}.",
        "Mon voyage m'a mené de {} à {}.",
        "En passant par {}, j'ai finalement atteint {}.",
        "À la suite de mon passage à {}, j'ai décidé de visiter {}.",
        "De {} jusqu'à {}, chaque étape était une aventure.",
        "Après avoir découvert {}, j'ai décidé de me rendre à {}.",
        "J'ai choisi {} comme prochaine destination après {}.",
        "Entre {} et {}, j'ai découvert des endroits merveilleux.",
        "J'ai quitté {} pour me diriger vers {}.",
        "Après avoir admiré {}, j'ai entrepris d'explorer {}.",
        "De {} à {}, j'ai vécu des moments inoubliables.",
        "Je suis passé(e) de {} à {} pour découvrir de nouveaux horizons.",
        "À la suite de ma visite à {}, j'ai décidé de me rendre à {}.",
        "Entre {} et {}, j'ai rencontré des personnes formidables.",
        "J'ai quitté {} pour m'aventurer à {}.",
        "Après avoir contemplé {}, j'ai décidé de visiter {}.",
        "Mon itinéraire m'a mené de {} à {}.",
        "En partant de {}, je me suis dirigé(e) vers {}.",
        "De {} à {}, chaque étape a été une source d'émerveillement.",
        "Après avoir exploré {}, j'ai continué ma route jusqu'à {}.",
        "En quittant {}, je suis allé(e) à {} pour découvrir de nouveaux paysages.",
        "Entre {} et {}, j'ai découvert une richesse culturelle incroyable.",
        "J'ai décidé de partir de {} pour me rendre à {}.",
        "Après avoir découvert {}, je me suis dirigé(e) vers {}.",
        "Ma visite à {} m'a inspiré(e) à explorer {}.",
        "En voyageant de {} à {}, j'ai été émerveillé(e) par la diversité.",
        "Après avoir contemplé {}, j'ai entrepris de visiter {}.",
        "Je suis allé(e) de {} jusqu'à {} pour explorer de nouveaux lieux.",
        "Après avoir passé du temps à {}, j'ai décidé de me rendre à {}.",
        "En découvrant {}, j'ai été attiré(e) par {}.",
        "De {} à {}, j'ai apprécié chaque moment de mon périple.",
        "Après avoir exploré {}, j'ai décidé de découvrir {}.",
        "Mon itinéraire m'a conduit de {} à {} pour une expérience unique.",
        "Après avoir visité {}, j'ai poursuivi mon voyage jusqu'à {}.",
        "J'ai choisi {} comme prochaine étape après être passé(e) par {}.",
        "De {} à {}, j'ai été fasciné(e) par la diversité des paysages.",
        "Après avoir découvert {}, j'ai décidé de me rendre à {} pour en voir plus.",
        "En voyageant de {} à {}, j'ai été surpris(e) par la richesse culturelle.",
        "Après avoir exploré {}, j'ai entrepris de découvrir {}.",
        "Je suis passé(e) de {} à {} pour une expérience enrichissante.",
        "Après avoir visité {}, j'ai poursuivi mon périple jusqu'à {}.",
        "En quittant {}, je me suis dirigé(e) vers {} pour de nouvelles découvertes.",
        "J'ai choisi {} comme prochaine destination après être passé(e) par {}.",
        "De {} à {}, j'ai été captivé(e) par la beauté des lieux.",
        "Après avoir passé du temps à {}, j'ai décidé de visiter {}.",
        "Mon voyage de {} à {} m'a offert une diversité incroyable.",
        "En partant de {}, je me suis rendu(e) à {} pour de nouvelles aventures.",
        "Après avoir découvert {}, j'ai décidé de me rendre à {} pour en voir plus.",
        "En voyageant de {} à {}, j'ai été surpris(e) par la richesse culturelle.",
        "Après avoir exploré {}, j'ai entrepris de découvrir {}.",
        "Je suis passé(e) de {} à {} pour une expérience enrichissante.",
        "Après avoir visité {}, j'ai poursuivi mon périple jusqu'à {}.",
        "En quittant {}, je me suis dirigé(e) vers {} pour de nouvelles découvertes.",
        "J'ai choisi {} comme prochaine destination après être passé(e) par {}.",
        "De {} à {}, j'ai été captivé(e) par la beauté des lieux.",
        "Après avoir passé du temps à {}, j'ai décidé de visiter {}.",
        "Mon voyage de {} à {} m'a offert une diversité incroyable.",
        "En partant de {}, je me suis rendu(e) à {} pour de nouvelles aventures.",
        "Je suis allé(e) de {} à {}.",
        "J'ai visité {} avant de découvrir {}.",
        "Après avoir exploré {}, je suis parti(e) à {}.",
        "De {} à {}, j'ai parcouru un long chemin.",
        "À la suite de mon séjour à {}, j'ai voyagé jusqu'à {}.",
        "Mon périple m'a mené de {} à {}.",
        "Je me suis rendu(e) de {} vers {}.",
        "Après {} est venu(e) {} lors de mon voyage.",
        "J'ai quitté {} pour me rendre à {}.",
        "En partant de {}, je suis arrivé(e) à {}.",
        "De {} jusqu'à {}, mon itinéraire était passionnant.",
        "J'ai exploré {} avant de me diriger vers {}.",
        "Ma route m'a conduit(e) de {} à {}.",
        "De {} à {}, j'ai découvert de nouveaux horizons.",
        "Après mon séjour à {}, j'ai continué vers {}.",
        "J'ai voyagé de {} à {} pour découvrir de nouvelles cultures.",
        "De {} jusqu'à {}, mon trajet a été plein de surprises.",
        "En partant de {} pour aller à {}, j'ai vécu des aventures incroyables.",
        "J'ai exploré {} avant de me rendre à {}.",
        "J'ai découvert {} après être passé(e) par {}.",
        "De {} à {}, j'ai fait un saut inattendu.",
        "En quittant {}, je me suis dirigé(e) vers {}.",
        "De {} à {}, j'ai fait une escale enrichissante.",
        "Après mon passage à {}, je suis parti(e) pour {}.",
        "J'ai continué mon voyage de {} à {}.",
        "De {} à {}, j'ai exploré de nouveaux horizons.",
        "Après {} est venu {} lors de mon périple.",
        "De {} à {}, j'ai fait une pause avant de repartir vers {}.",
        "J'ai fait étape à {} avant de me rendre à {}.",
        "En partant de {}, je suis arrivé(e) à {}.",
        "J'ai exploré {} avant de me diriger vers {}.",
        "Ma route m'a conduit(e) de {} à {}.",
        "De {} à {}, j'ai découvert de nouveaux horizons.",
        "Après mon séjour à {}, j'ai continué vers {}.",
        "J'ai voyagé de {} à {} pour découvrir de nouvelles cultures.",
        "De {} jusqu'à {}, mon trajet a été plein de surprises.",
        "En partant de {} pour aller à {}, j'ai vécu des aventures incroyables.",
        "Ma visite à {} a été suivie par un passage à {}.",
        "De {} à {}, j'ai apprécié chaque étape de mon voyage.",
        "Après avoir quitté {}, je me suis dirigé(e) vers {}.",
        "J'ai entrepris mon voyage de {} à {}.",
        "En passant de {} à {}, j'ai rencontré des personnes formidables.",
        "De {} à {}, mon parcours a été riche en découvertes.",
        "Après {} vient {} dans mon itinéraire.",
        "J'ai découvert {} après être passé(e) par {}.",
        "De {} à {}, j'ai fait un saut inattendu.",
        "En quittant {}, je me suis dirigé(e) vers {}.",
        "De {} à {}, j'ai fait une escale enrichissante.",
        "Après mon passage à {}, je suis parti(e) pour {}.",
        "J'ai continué mon voyage de {} à {}.",
        "De {} à {}, j'ai exploré de nouveaux horizons.",
        "Après {} est venu {} lors de mon périple.",
        "De {} à {}, j'ai fait une pause avant de repartir vers {}.",
        "J'ai fait étape à {} avant de me rendre à {}.",
        "Après avoir exploré {}, je suis parti(e) à {}.",
        "De {} à {}, j'ai parcouru un long chemin.",
        "À la suite de mon séjour à {}, j'ai voyagé jusqu'à {}.",
        "En partant de {}, je me suis rendu(e) à {}.",
        "Mon voyage de {} à {} était incroyable.",
        "Lors de mon passage de {} à {}, j'ai été émerveillé(e).",
        "Nous avons voyagé de {} à {} ensemble.",
        "En visitant {} et ensuite {}, j'ai appris beaucoup de choses.",
        "Ils ont exploré {} avant de se diriger vers {}.",
        "Elles ont parcouru un long chemin de {} à {}.",
        "Il est allé de {} à {} pour ses vacances.",
        "Elle est partie de {} pour découvrir {}.",
        "On a visité {} et ensuite {} pour une expérience inoubliable.",
        "Vous êtes allé(e) de {} à {} pour vos vacances.",
        "En passant de {} à {}, tu as trouvé quelque chose d'intéressant.",
        "Lors de votre séjour de {} à {}, vous avez vu beaucoup de choses.",
        "Ils ont voyagé de {} à {} pour affaires.",
        "Elles sont parties de {} à {} pour une escapade.",
        "Il a parcouru un long chemin de {} à {}.",
        "Elle a découvert {} après avoir visité {}.",
        "On est allé de {} à {} pour des raisons spéciales.",
        "Nous sommes partis de {} à {} pour explorer.",
        "En visitant {} et ensuite {}, nous avons réalisé beaucoup de choses.",
        "Vous avez exploré {} avant de vous rendre à {}.",
        "En passant de {} à {}, vous avez eu une aventure incroyable.",
        "Ils sont partis de {} à {} pour des vacances reposantes.",
        "Elles ont voyagé de {} à {} pour une expérience enrichissante.",
        "Il est allé de {} à {} pour se ressourcer.",
        "Elle est partie de {} pour découvrir {} et s'y installer.",
        "On a visité {} et ensuite {} pour une escapade culturelle.",
        "Vous êtes allé(e) de {} à {} pour un changement de paysage.",
        "En passant de {} à {}, tu as découvert de nouvelles perspectives.",
        "Lors de votre séjour de {} à {}, vous avez vécu des moments uniques.",
        "Ils ont voyagé de {} à {} pour des affaires importantes.",
        "Elles sont parties de {} à {} pour une aventure mémorable.",
        "Lors de mon voyage, de {} à {}, j'ai découvert de nouveaux horizons.",
        "Parti(e) de {} et arrivé(e) à {}, un voyage inoubliable.",
        "En partant de {}, je me suis dirigé(e) vers {}.",
        "C'est de {} à {} que j'ai tracé mon itinéraire.",
        "{} m'a enchanté(e) avant d'atteindre {}.",
        "J'ai choisi de passer par {} avant d'explorer {}."
        "J'ai choisi de passer par {}.",
    ]

# %%
sentences = []

# %%
for _ in range(len(patterns)):
        pattern = random.choice(patterns)  # Sélection aléatoire d'un modèle de phrase
        pattern_elements = pattern.count(
            "{}"
        )  # Compter le nombre d'emplacements à remplir
        available_cities = villes["name"].tolist()

        if pattern_elements > len(available_cities):
            pattern_elements = len(available_cities)

        replacements = random.sample(
            available_cities, pattern_elements
        )  # Sélectionner les éléments à remplacer
        line = pattern.format(
            *replacements
        )  # Formater la phrase avec les éléments sélectionnés

        line_without_spaces = line.replace(" ", "")
        depart_replace = replacements[0].replace(" ", "")
        dest_replace = replacements[1].replace(" ", "")

        sentences.append(
            {
                "TEXT": line,
                "DEPART": depart_replace,
                "START_DEPART": line_without_spaces.find(depart_replace) + 1,
                "END_DEPART": len(depart_replace) + line_without_spaces.find(depart_replace),
                "DEP": "DEP",
                "DESTINATION": dest_replace,
                "START_DEST": line_without_spaces.find(dest_replace) + 1,
                "END_DEST": line_without_spaces.find(dest_replace) + len(dest_replace),
                "DEST": "DEST",
            }
        )

# %%
sentences
# Out:
# [{'TEXT': "J'ai décidé de faire une halte à Chenac-Saint-Seurin-d'Uzet pour une expérience culturelle unique avant de rejoindre Saint-Hilaire-la-Gravelle pour la suite de mon voyage.",
#   'DEPART': "Chenac-Saint-Seurin-d'Uzet",
#   'START_DEPART': 27,
#   'END_DEPART': 52,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Hilaire-la-Gravelle',
#   'START_DEST': 102,
#   'END_DEST': 126,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant de Anstaing à Saint-Martin-lÃ¨s-Melle, tu as trouvé quelque chose d'intéressant.",
#   'DEPART': 'Anstaing',
#   'START_DEPART': 12,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Martin-lÃ¨s-Melle',
#   'START_DEST': 21,
#   'END_DEST': 43,
#   'DEST': 'DEST'},
#  {'TEXT': "Après un séjour enrichissant à Vaucogne, j'ai pris la décision de me rendre à Chamant pour son paysage époustouflant.",
#   'DEPART': 'Vaucogne',
#   'START_DEPART': 27,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chamant',
#   'START_DEST': 65,
#   'END_DEST': 71,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant la modernité de Massac, je suis allé(e) à Miniac-Morvan pour me plonger dans la nature sauvage.',
#   'DEPART': 'Massac',
#   'START_DEPART': 24,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Miniac-Morvan',
#   'START_DEST': 45,
#   'END_DEST': 57,
#   'DEST': 'DEST'},
#  {'TEXT': "Entre Moncaup et Damouzy, j'ai découvert des endroits merveilleux.",
#   'DEPART': 'Moncaup',
#   'START_DEPART': 6,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Damouzy',
#   'START_DEST': 15,
#   'END_DEST': 21,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté ma ville natale de Saint-EusÃ¨be pour me plonger dans l'effervescence de Fourilles et sa vie nocturne animée.",
#   'DEPART': 'Saint-EusÃ¨be',
#   'START_DEPART': 26,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'Fourilles',
#   'START_DEST': 73,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de Frettecuisse à Amions, j'ai été surpris(e) par la richesse culturelle.",
#   'DEPART': 'Frettecuisse',
#   'START_DEPART': 14,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Amions',
#   'START_DEST': 27,
#   'END_DEST': 32,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de Saint-Mars-sur-Colmont à Saint-Offenge, j'ai été surpris(e) par la richesse culturelle.",
#   'DEPART': 'Saint-Mars-sur-Colmont',
#   'START_DEPART': 14,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Offenge',
#   'START_DEST': 37,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': 'Ils ont exploré Kerfourn avant de se diriger vers ChÃ¢lonvillars pour un séjour reposant au bord de la mer.',
#   'DEPART': 'Kerfourn',
#   'START_DEPART': 14,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'ChÃ¢lonvillars',
#   'START_DEST': 42,
#   'END_DEST': 55,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai continué mon voyage de Giraumont à Montussaint.",
#   'DEPART': 'Giraumont',
#   'START_DEPART': 24,
#   'END_DEPART': 32,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montussaint',
#   'START_DEST': 34,
#   'END_DEST': 44,
#   'DEST': 'DEST'},
#  {'TEXT': "De Hagenthal-le-Haut à Ã\x89tavigny, j'ai fait une escale enrichissante.",
#   'DEPART': 'Hagenthal-le-Haut',
#   'START_DEPART': 3,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ã\x89tavigny',
#   'START_DEST': 21,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': "Après Chaumousey est venu Sabazan dans mon itinéraire, m'offrant une transition parfaite entre deux expériences uniques.",
#   'DEPART': 'Chaumousey',
#   'START_DEPART': 6,
#   'END_DEPART': 15,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sabazan',
#   'START_DEST': 23,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Marvaux-Vieux pour aller à Saint-Firmin, j'ai vécu des aventures incroyables.",
#   'DEPART': 'Marvaux-Vieux',
#   'START_DEPART': 12,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Firmin',
#   'START_DEST': 35,
#   'END_DEST': 46,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté BÃ©deille pour me rendre à Le Petit-Celland.",
#   'DEPART': 'BÃ©deille',
#   'START_DEPART': 11,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'LePetit-Celland',
#   'START_DEST': 33,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après mon passage à Saint-Germain-le-Vieux, je suis parti(e) pour ScillÃ© pour une expérience de détente et de bien-être.',
#   'DEPART': 'Saint-Germain-le-Vieux',
#   'START_DEPART': 17,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'ScillÃ©',
#   'START_DEST': 58,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai exploré ChÃ¢telblanc avant de me diriger vers Baudre.",
#   'DEPART': 'ChÃ¢telblanc',
#   'START_DEPART': 12,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Baudre',
#   'START_DEST': 44,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Grande-RiviÃ¨re à Voyenne m'a permis de constater la diversité incroyable des paysages rencontrés en chemin.",
#   'DEPART': 'Grande-RiviÃ¨re',
#   'START_DEPART': 12,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Voyenne',
#   'START_DEST': 28,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les richesses artistiques de Dehault, j'ai pris la direction de Saint-Nizier-d'Azergues pour une immersion différente.",
#   'DEPART': 'Dehault',
#   'START_DEPART': 45,
#   'END_DEPART': 51,
#   'DEP': 'DEP',
#   'DESTINATION': "Saint-Nizier-d'Azergues",
#   'START_DEST': 74,
#   'END_DEST': 96,
#   'DEST': 'DEST'},
#  {'TEXT': 'Nous avons voyagé de Saint-LÃ©ons à Mison ensemble.',
#   'DEPART': 'Saint-LÃ©ons',
#   'START_DEPART': 18,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Mison',
#   'START_DEST': 31,
#   'END_DEST': 35,
#   'DEST': 'DEST'},
#  {'TEXT': 'Lors de votre séjour de Mautes à Suaux, vous avez vu beaucoup de choses.',
#   'DEPART': 'Mautes',
#   'START_DEPART': 20,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Suaux',
#   'START_DEST': 27,
#   'END_DEST': 31,
#   'DEST': 'DEST'},
#  {'TEXT': 'Ils sont partis de Saint-Sulpice-les-Champs à HarbonniÃ¨res pour des vacances reposantes.',
#   'DEPART': 'Saint-Sulpice-les-Champs',
#   'START_DEPART': 16,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'HarbonniÃ¨res',
#   'START_DEST': 41,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "En découvrant Givonne, j'ai été immergé(e) dans la culture locale avant de me rendre à Pageas pour explorer de nouvelles traditions.",
#   'DEPART': 'Givonne',
#   'START_DEPART': 13,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pageas',
#   'START_DEST': 73,
#   'END_DEST': 78,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par OgnÃ©ville, j'ai exploré les quartiers artistiques avant de me rendre à Heugas pour une immersion spirituelle.",
#   'DEPART': 'OgnÃ©ville',
#   'START_DEPART': 13,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Heugas',
#   'START_DEST': 74,
#   'END_DEST': 79,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai entrepris mon voyage de La Besseyre-Saint-Mary à Ecquetot.",
#   'DEPART': 'LaBesseyre-Saint-Mary',
#   'START_DEPART': 25,
#   'END_DEPART': 45,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ecquetot',
#   'START_DEST': 47,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai visité Tanay avant de découvrir Martincourt.",
#   'DEPART': 'Tanay',
#   'START_DEPART': 11,
#   'END_DEPART': 15,
#   'DEP': 'DEP',
#   'DESTINATION': 'Martincourt',
#   'START_DEST': 32,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par Rebourguil avant d'explorer Saurais.",
#   'DEPART': 'Rebourguil',
#   'START_DEPART': 22,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saurais',
#   'START_DEST': 47,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "De Castelmary à Sainte-FÃ©rÃ©ole, j'ai fait un saut inattendu.",
#   'DEPART': 'Castelmary',
#   'START_DEPART': 3,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-FÃ©rÃ©ole',
#   'START_DEST': 14,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir découvert La BelliÃ¨re, je me suis dirigé(e) vers Chambonchard.',
#   'DEPART': 'LaBelliÃ¨re',
#   'START_DEPART': 20,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chambonchard',
#   'START_DEST': 53,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert Saint-Germain-des-Angles, j'ai décidé de me rendre à Pradelles-en-Val.",
#   'DEPART': 'Saint-Germain-des-Angles',
#   'START_DEPART': 20,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pradelles-en-Val',
#   'START_DEST': 66,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Vendelles, j'ai continué ma route jusqu'à HoÃ©ville.",
#   'DEPART': 'Vendelles',
#   'START_DEPART': 18,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'HoÃ©ville',
#   'START_DEST': 54,
#   'END_DEST': 62,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la route des explorateurs culinaires de Roquefort-sur-Garonne à Arcenant en dégustant des mets locaux authentiques.",
#   'DEPART': 'Roquefort-sur-Garonne',
#   'START_DEPART': 44,
#   'END_DEPART': 64,
#   'DEP': 'DEP',
#   'DESTINATION': 'Arcenant',
#   'START_DEST': 66,
#   'END_DEST': 73,
#   'DEST': 'DEST'},
#  {'TEXT': "De OrignÃ© jusqu'à FrÃ©chou-FrÃ©chet, mon trajet a été ponctué de découvertes surprenantes qui ont enrichi mon expérience.",
#   'DEPART': 'OrignÃ©',
#   'START_DEPART': 3,
#   'END_DEPART': 9,
#   'DEP': 'DEP',
#   'DESTINATION': 'FrÃ©chou-FrÃ©chet',
#   'START_DEST': 17,
#   'END_DEST': 33,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai été inspiré(e) par l'authenticité de Hombourg-Haut avant de continuer mon voyage vers Bourron-Marlotte pour une aventure hors du commun.",
#   'DEPART': 'Hombourg-Haut',
#   'START_DEPART': 37,
#   'END_DEPART': 49,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bourron-Marlotte',
#   'START_DEST': 79,
#   'END_DEST': 94,
#   'DEST': 'DEST'},
#  {'TEXT': "De Rocheville à NÃ©vez, j'ai fait une pause avant de repartir vers Doix lÃ¨s Fontaines.",
#   'DEPART': 'Rocheville',
#   'START_DEPART': 3,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'NÃ©vez',
#   'START_DEST': 14,
#   'END_DEST': 19,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après mon passage à CouÃ«ron, je suis parti(e) pour Fontanes pour une expérience de détente et de bien-être.',
#   'DEPART': 'CouÃ«ron',
#   'START_DEPART': 17,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Fontanes',
#   'START_DEST': 44,
#   'END_DEST': 51,
#   'DEST': 'DEST'},
#  {'TEXT': "En visitant Breuvannes-en-Bassigny et ensuite Firfol, j'ai appris à connaître les différentes facettes d'un même pays.",
#   'DEPART': 'Breuvannes-en-Bassigny',
#   'START_DEPART': 11,
#   'END_DEPART': 32,
#   'DEP': 'DEP',
#   'DESTINATION': 'Firfol',
#   'START_DEST': 42,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté Hodent pour me rendre à DÃ©mu.",
#   'DEPART': 'Hodent',
#   'START_DEPART': 11,
#   'END_DEPART': 16,
#   'DEP': 'DEP',
#   'DESTINATION': 'DÃ©mu',
#   'START_DEST': 30,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir rencontré des habitants sympathiques à Fontaines, j'ai poursuivi mon chemin vers Pas-en-Artois pour explorer davantage.",
#   'DEPART': 'Fontaines',
#   'START_DEPART': 45,
#   'END_DEPART': 53,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pas-en-Artois',
#   'START_DEST': 81,
#   'END_DEST': 93,
#   'DEST': 'DEST'},
#  {'TEXT': 'Je suis passé(e) de Vireux-Molhain à Salettes pour une expérience enrichissante.',
#   'DEPART': 'Vireux-Molhain',
#   'START_DEPART': 17,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Salettes',
#   'START_DEST': 32,
#   'END_DEST': 39,
#   'DEST': 'DEST'},
#  {'TEXT': 'Elles ont parcouru un long chemin de Corbara à Dosnon.',
#   'DEPART': 'Corbara',
#   'START_DEPART': 31,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Dosnon',
#   'START_DEST': 39,
#   'END_DEST': 44,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré AvrillÃ©-les-Ponceaux, je suis parti(e) à Huppy.',
#   'DEPART': 'AvrillÃ©-les-Ponceaux',
#   'START_DEPART': 18,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'Huppy',
#   'START_DEST': 55,
#   'END_DEST': 59,
#   'DEST': 'DEST'},
#  {'TEXT': "Après un séjour enrichissant à Bellevigny, j'ai pris la décision de me rendre à Aston pour son paysage époustouflant.",
#   'DEPART': 'Bellevigny',
#   'START_DEPART': 27,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Aston',
#   'START_DEST': 67,
#   'END_DEST': 71,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Fesches-le-ChÃ¢tel, je me suis rendu(e) à Cazaril-TambourÃ¨s.',
#   'DEPART': 'Fesches-le-ChÃ¢tel',
#   'START_DEPART': 12,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cazaril-TambourÃ¨s',
#   'START_DEST': 48,
#   'END_DEST': 65,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Bouverans, je me suis dirigé(e) vers Lorlanges.',
#   'DEPART': 'Bouverans',
#   'START_DEPART': 11,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Lorlanges',
#   'START_DEST': 42,
#   'END_DEST': 50,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Montaigu-les-Bois, je me suis dirigé(e) vers BÃ©thencourt-sur-Somme pour de nouvelles découvertes.',
#   'DEPART': 'Montaigu-les-Bois',
#   'START_DEPART': 11,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'BÃ©thencourt-sur-Somme',
#   'START_DEST': 50,
#   'END_DEST': 71,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Saint-Pabu, j'ai poursuivi mon périple jusqu'à Sainte-Foy-Saint-Sulpice.",
#   'DEPART': 'Saint-Pabu',
#   'START_DEPART': 17,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-Foy-Saint-Sulpice',
#   'START_DEST': 58,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple m'a mené de SÃ©lestat à Saint-Paul-en-Chablais.",
#   'DEPART': 'SÃ©lestat',
#   'START_DEPART': 20,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Paul-en-Chablais',
#   'START_DEST': 30,
#   'END_DEST': 51,
#   'DEST': 'DEST'},
#  {'TEXT': "En quittant La Ronde-Haye, j'ai été ému(e) par la spiritualité avant de me rendre à Goudelancourt-lÃ¨s-Berrieux pour une expérience spirituelle différente.",
#   'DEPART': 'LaRonde-Haye',
#   'START_DEPART': 11,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Goudelancourt-lÃ¨s-Berrieux',
#   'START_DEST': 70,
#   'END_DEST': 96,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai été attiré(e) par les festivités animées de Allerey-sur-SaÃ´ne avant de me rendre à GentÃ© pour un contraste apaisant.",
#   'DEPART': 'Allerey-sur-SaÃ´ne',
#   'START_DEPART': 42,
#   'END_DEPART': 59,
#   'DEP': 'DEP',
#   'DESTINATION': 'GentÃ©',
#   'START_DEST': 76,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "De Saint-Vincent-de-Paul jusqu'à LÃ©alvillers, chaque étape de mon itinéraire a été marquée par des rencontres inspirantes.",
#   'DEPART': 'Saint-Vincent-de-Paul',
#   'START_DEPART': 3,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'LÃ©alvillers',
#   'START_DEST': 31,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': "De Courdimanche à Le Mans, j'ai fait une escale enrichissante.",
#   'DEPART': 'Courdimanche',
#   'START_DEPART': 3,
#   'END_DEPART': 14,
#   'DEP': 'DEP',
#   'DESTINATION': 'LeMans',
#   'START_DEST': 16,
#   'END_DEST': 21,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par Lucelle avant d'explorer Valframbert.J'ai choisi de passer par Humbercamps.",
#   'DEPART': 'Lucelle',
#   'START_DEPART': 22,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Valframbert',
#   'START_DEST': 44,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Arthaz-Pont-Notre-Dame, j'ai été surpris(e) par la diversité culturelle avant de me diriger vers Bonrepos-sur-Aussonnelle pour un tout autre paysage.",
#   'DEPART': 'Arthaz-Pont-Notre-Dame',
#   'START_DEPART': 13,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bonrepos-sur-Aussonnelle',
#   'START_DEST': 97,
#   'END_DEST': 120,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir rencontré des habitants sympathiques à Pruines, j'ai poursuivi mon chemin vers Chichey pour explorer davantage.",
#   'DEPART': 'Pruines',
#   'START_DEPART': 45,
#   'END_DEPART': 51,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chichey',
#   'START_DEST': 79,
#   'END_DEST': 85,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par LuxÃ©mont-et-Villotte, j'ai finalement atteint Haussez.",
#   'DEPART': 'LuxÃ©mont-et-Villotte',
#   'START_DEPART': 13,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Haussez',
#   'START_DEST': 56,
#   'END_DEST': 62,
#   'DEST': 'DEST'},
#  {'TEXT': "De Saint-Denis-d'Anjou jusqu'à NÃ©nigan, j'ai suivi les chemins de traverse pour découvrir des panoramas spectaculaires.",
#   'DEPART': "Saint-Denis-d'Anjou",
#   'START_DEPART': 3,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'NÃ©nigan',
#   'START_DEST': 29,
#   'END_DEST': 36,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Quelmes, j'ai traversé des vallées verdoyantes pour arriver à Valloire et ses montagnes escarpées.",
#   'DEPART': 'Quelmes',
#   'START_DEPART': 12,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Valloire',
#   'START_DEST': 65,
#   'END_DEST': 72,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par PrÃ©aux avant d'explorer Vieux-Moulin et d'y découvrir une scène artistique bouillonnante.",
#   'DEPART': 'PrÃ©aux',
#   'START_DEPART': 22,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vieux-Moulin',
#   'START_DEST': 44,
#   'END_DEST': 55,
#   'DEST': 'DEST'},
#  {'TEXT': "Après une halte à Augerans, j'ai continué mon voyage jusqu'à Essuiles pour vivre une aventure inattendue.",
#   'DEPART': 'Augerans',
#   'START_DEPART': 15,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Essuiles',
#   'START_DEST': 52,
#   'END_DEST': 59,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après mon passage à Saint-ClÃ©ment-sur-Valsonne, je suis parti(e) pour Stosswihr pour une expérience de détente et de bien-être.',
#   'DEPART': 'Saint-ClÃ©ment-sur-Valsonne',
#   'START_DEPART': 17,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Stosswihr',
#   'START_DEST': 63,
#   'END_DEST': 71,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir contemplé la beauté naturelle de La Mothe-Saint-HÃ©ray, j'ai choisi de me rendre à Pusy-et-Ã\x89penoux pour explorer ses monuments historiques.",
#   'DEPART': 'LaMothe-Saint-HÃ©ray',
#   'START_DEPART': 39,
#   'END_DEPART': 58,
#   'DEP': 'DEP',
#   'DESTINATION': 'Pusy-et-Ã\x89penoux',
#   'START_DEST': 81,
#   'END_DEST': 96,
#   'DEST': 'DEST'},
#  {'TEXT': 'Mon voyage de Beux à Chevanceaux était incroyable.',
#   'DEPART': 'Beux',
#   'START_DEPART': 12,
#   'END_DEPART': 15,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chevanceaux',
#   'START_DEST': 17,
#   'END_DEST': 27,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai exploré Gex avant de me diriger vers Saint-Souplet-sur-Py.",
#   'DEPART': 'Gex',
#   'START_DEPART': 12,
#   'END_DEPART': 14,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Souplet-sur-Py',
#   'START_DEST': 35,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Chavenon, j'ai entrepris de découvrir RÃ©malard en Perche.",
#   'DEPART': 'Chavenon',
#   'START_DEPART': 18,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'RÃ©malardenPerche',
#   'START_DEST': 51,
#   'END_DEST': 67,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré les quartiers animés de Trenal, je me suis ressourcé(e) dans la quiétude de Chanas.',
#   'DEPART': 'Trenal',
#   'START_DEPART': 38,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chanas',
#   'START_DEST': 81,
#   'END_DEST': 86,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après Cintegabelle est venu Sainte-Marie lors de mon périple.',
#   'DEPART': 'Cintegabelle',
#   'START_DEPART': 6,
#   'END_DEPART': 17,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-Marie',
#   'START_DEST': 25,
#   'END_DEST': 36,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Saint-Junien-les-Combes, je suis arrivé(e) à Partinello.',
#   'DEPART': 'Saint-Junien-les-Combes',
#   'START_DEPART': 12,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Partinello',
#   'START_DEST': 52,
#   'END_DEST': 61,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Saint-Aubin, j'ai continué ma route jusqu'à Brainville.",
#   'DEPART': 'Saint-Aubin',
#   'START_DEPART': 18,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Brainville',
#   'START_DEST': 56,
#   'END_DEST': 65,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Pont-Croix à Saint-Georges-sur-Erve pour vos vacances.',
#   'DEPART': 'Pont-Croix',
#   'START_DEPART': 18,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Georges-sur-Erve',
#   'START_DEST': 29,
#   'END_DEST': 50,
#   'DEST': 'DEST'},
#  {'TEXT': "En découvrant les coutumes authentiques de Santenay, j'ai poursuivi mon périple vers Marais-Vernier pour de nouvelles découvertes.",
#   'DEPART': 'Santenay',
#   'START_DEPART': 38,
#   'END_DEPART': 45,
#   'DEP': 'DEP',
#   'DESTINATION': 'Marais-Vernier',
#   'START_DEST': 74,
#   'END_DEST': 87,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les traditions uniques de Saint-Alban, j'ai continué vers Lissac-sur-Couze pour vivre de nouvelles expériences.",
#   'DEPART': 'Saint-Alban',
#   'START_DEPART': 42,
#   'END_DEPART': 52,
#   'DEP': 'DEP',
#   'DESTINATION': 'Lissac-sur-Couze',
#   'START_DEST': 70,
#   'END_DEST': 85,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir passé du temps à Saint-Ã\x89tienne-sur-Suippe, j'ai décidé de visiter Brunembert.",
#   'DEPART': 'Saint-Ã\x89tienne-sur-Suippe',
#   'START_DEPART': 24,
#   'END_DEPART': 48,
#   'DEP': 'DEP',
#   'DESTINATION': 'Brunembert',
#   'START_DEST': 69,
#   'END_DEST': 78,
#   'DEST': 'DEST'},
#  {'TEXT': "En visitant Chaudenay-le-ChÃ¢teau et ensuite Cussy-les-Forges, j'ai appris à connaître les différentes facettes d'un même pays.",
#   'DEPART': 'Chaudenay-le-ChÃ¢teau',
#   'START_DEPART': 11,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cussy-les-Forges',
#   'START_DEST': 41,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Le Creusot, j'ai découvert les richesses cachées de Gavray à travers des expériences authentiques.",
#   'DEPART': 'LeCreusot',
#   'START_DEPART': 12,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Gavray',
#   'START_DEST': 56,
#   'END_DEST': 61,
#   'DEST': 'DEST'},
#  {'TEXT': "Elle est partie de Ciboure pour découvrir Fay et s'y installer.",
#   'DEPART': 'Ciboure',
#   'START_DEPART': 16,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Fay',
#   'START_DEST': 36,
#   'END_DEST': 38,
#   'DEST': 'DEST'},
#  {'TEXT': 'Je suis allé(e) de VÅ\x93llerdingen à MagnÃ©.',
#   'DEPART': 'VÅ\x93llerdingen',
#   'START_DEPART': 16,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'MagnÃ©',
#   'START_DEST': 30,
#   'END_DEST': 35,
#   'DEST': 'DEST'},
#  {'TEXT': "De Melincourt à Saint-Hilaire-sur-Risle, j'ai suivi les traces des explorateurs anciens tout en explorant des attractions modernes.",
#   'DEPART': 'Melincourt',
#   'START_DEPART': 3,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Hilaire-sur-Risle',
#   'START_DEST': 14,
#   'END_DEST': 36,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Aussonce, je me suis dirigé(e) vers Durfort-Lacapelette pour une immersion dans des traditions ancestrales.',
#   'DEPART': 'Aussonce',
#   'START_DEPART': 12,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Durfort-Lacapelette',
#   'START_DEST': 42,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': "De Neuville-sur-Brenne jusqu'à Saint-Marc-la-Lande, j'ai suivi les sentiers des anciens habitants tout en découvrant des cultures contemporaines.",
#   'DEPART': 'Neuville-sur-Brenne',
#   'START_DEPART': 3,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Marc-la-Lande',
#   'START_DEST': 29,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple a commencé à Ã\x89terpigny où j'ai été accueilli(e) chaleureusement avant de me rendre à Montfalcon.",
#   'DEPART': 'Ã\x89terpigny',
#   'START_DEPART': 21,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montfalcon',
#   'START_DEST': 83,
#   'END_DEST': 92,
#   'DEST': 'DEST'},
#  {'TEXT': "Après un séjour enrichissant à SÃ©rignac-sur-Garonne, j'ai pris la décision de me rendre à Neuilly-en-Dun pour son paysage époustouflant.",
#   'DEPART': 'SÃ©rignac-sur-Garonne',
#   'START_DEPART': 27,
#   'END_DEPART': 47,
#   'DEP': 'DEP',
#   'DESTINATION': 'Neuilly-en-Dun',
#   'START_DEST': 78,
#   'END_DEST': 91,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après Esse est venu VillechÃ©tif lors de mon périple.',
#   'DEPART': 'Esse',
#   'START_DEPART': 6,
#   'END_DEPART': 9,
#   'DEP': 'DEP',
#   'DESTINATION': 'VillechÃ©tif',
#   'START_DEST': 17,
#   'END_DEST': 28,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Matzenheim, j'ai continué ma route jusqu'à Marais-Vernier.",
#   'DEPART': 'Matzenheim',
#   'START_DEPART': 18,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Marais-Vernier',
#   'START_DEST': 55,
#   'END_DEST': 68,
#   'DEST': 'DEST'},
#  {'TEXT': 'Il est allé de Honskirch à Bazordan pour se ressourcer.',
#   'DEPART': 'Honskirch',
#   'START_DEPART': 12,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bazordan',
#   'START_DEST': 22,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté ma ville natale de LÃ©vis-Saint-Nom pour me plonger dans l'effervescence de Ponson-Dessus et sa vie nocturne animée.",
#   'DEPART': 'LÃ©vis-Saint-Nom',
#   'START_DEPART': 26,
#   'END_DEPART': 41,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ponson-Dessus',
#   'START_DEST': 76,
#   'END_DEST': 88,
#   'DEST': 'DEST'},
#  {'TEXT': "En visitant Momuy et ensuite PouanÃ§ay, j'ai appris à connaître les différentes facettes d'un même pays.",
#   'DEPART': 'Momuy',
#   'START_DEPART': 11,
#   'END_DEPART': 15,
#   'DEP': 'DEP',
#   'DESTINATION': 'PouanÃ§ay',
#   'START_DEST': 25,
#   'END_DEST': 33,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par TrÃ©prel avant d'explorer Soing-Cubry-Charentenay.J'ai choisi de passer par Milhars.",
#   'DEPART': 'TrÃ©prel',
#   'START_DEPART': 22,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Soing-Cubry-Charentenay',
#   'START_DEST': 45,
#   'END_DEST': 67,
#   'DEST': 'DEST'},
#  {'TEXT': 'Il est allé de Les Arcs à Empeaux pour ses vacances et y a trouvé une atmosphère de fête permanente.',
#   'DEPART': 'LesArcs',
#   'START_DEPART': 12,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Empeaux',
#   'START_DEST': 20,
#   'END_DEST': 26,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Saint-Arnoult, je me suis dirigé(e) vers Montertelot pour de nouvelles découvertes.',
#   'DEPART': 'Saint-Arnoult',
#   'START_DEPART': 11,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montertelot',
#   'START_DEST': 46,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir profité de la convivialité de Saint-Augustin-des-Bois, j'ai repris ma route vers Marcilly-la-Campagne pour découvrir de nouvelles perspectives.",
#   'DEPART': 'Saint-Augustin-des-Bois',
#   'START_DEPART': 36,
#   'END_DEPART': 58,
#   'DEP': 'DEP',
#   'DESTINATION': 'Marcilly-la-Campagne',
#   'START_DEST': 81,
#   'END_DEST': 100,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi Belmont-Tramonet comme prochaine destination après être passé(e) par Thaumiers.",
#   'DEPART': 'Belmont-Tramonet',
#   'START_DEPART': 11,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Thaumiers',
#   'START_DEST': 72,
#   'END_DEST': 80,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert les vestiges anciens de Bouquemont, j'ai pris le chemin de Chenay pour une immersion dans la nature.",
#   'DEPART': 'Bouquemont',
#   'START_DEPART': 40,
#   'END_DEPART': 49,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chenay',
#   'START_DEST': 69,
#   'END_DEST': 74,
#   'DEST': 'DEST'},
#  {'TEXT': "De Collonges-lÃ¨s-BÃ©vy à Cornay, j'ai fait une escale enrichissante.",
#   'DEPART': 'Collonges-lÃ¨s-BÃ©vy',
#   'START_DEPART': 3,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cornay',
#   'START_DEST': 24,
#   'END_DEST': 29,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Rouffignac-de-SigoulÃ¨s, j'ai exploré les quartiers artistiques avant de me rendre à Yvrencheux pour une immersion spirituelle.",
#   'DEPART': 'Rouffignac-de-SigoulÃ¨s',
#   'START_DEPART': 13,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Yvrencheux',
#   'START_DEST': 87,
#   'END_DEST': 96,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir profité de la convivialité de FertrÃ¨ve, j'ai repris ma route vers Geishouse pour découvrir de nouvelles perspectives.",
#   'DEPART': 'FertrÃ¨ve',
#   'START_DEPART': 36,
#   'END_DEPART': 44,
#   'DEP': 'DEP',
#   'DESTINATION': 'Geishouse',
#   'START_DEST': 67,
#   'END_DEST': 75,
#   'DEST': 'DEST'},
#  {'TEXT': "De Villedieu-le-ChÃ¢teau à Nancy-sur-Cluses, j'ai apprécié chaque étape de mon voyage.",
#   'DEPART': 'Villedieu-le-ChÃ¢teau',
#   'START_DEPART': 3,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Nancy-sur-Cluses',
#   'START_DEST': 25,
#   'END_DEST': 40,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir apprécié la gastronomie de Gonfaron, j'ai repris ma route vers Azas pour une exploration plus approfondie.",
#   'DEPART': 'Gonfaron',
#   'START_DEPART': 34,
#   'END_DEPART': 41,
#   'DEP': 'DEP',
#   'DESTINATION': 'Azas',
#   'START_DEST': 64,
#   'END_DEST': 67,
#   'DEST': 'DEST'},
#  {'TEXT': "Après un séjour enrichissant à Le Bar-sur-Loup, j'ai pris la décision de me rendre à ChÃ¢tel-Censoir pour son paysage époustouflant.",
#   'DEPART': 'LeBar-sur-Loup',
#   'START_DEPART': 27,
#   'END_DEPART': 40,
#   'DEP': 'DEP',
#   'DESTINATION': 'ChÃ¢tel-Censoir',
#   'START_DEST': 71,
#   'END_DEST': 85,
#   'DEST': 'DEST'},
#  {'TEXT': 'On a visité Soussac et ensuite Bretigny pour une expérience culinaire inégalée.',
#   'DEPART': 'Soussac',
#   'START_DEPART': 10,
#   'END_DEPART': 16,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bretigny',
#   'START_DEST': 26,
#   'END_DEST': 33,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir arpenté les ruelles étroites de Sergenaux, j'ai pris la direction de Wingen-sur-Moder pour une vue panoramique.",
#   'DEPART': 'Sergenaux',
#   'START_DEPART': 38,
#   'END_DEPART': 46,
#   'DEP': 'DEP',
#   'DESTINATION': 'Wingen-sur-Moder',
#   'START_DEST': 69,
#   'END_DEST': 84,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Cisternes-la-ForÃªt, j'ai découvert les richesses cachées de Sauveterre-de-Comminges à travers des expériences authentiques.",
#   'DEPART': 'Cisternes-la-ForÃªt',
#   'START_DEPART': 12,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sauveterre-de-Comminges',
#   'START_DEST': 66,
#   'END_DEST': 88,
#   'DEST': 'DEST'},
#  {'TEXT': "En visitant LargentiÃ¨re, j'ai été inspiré(e) par l'histoire avant de découvrir les merveilles de Muides-sur-Loire.",
#   'DEPART': 'LargentiÃ¨re',
#   'START_DEPART': 11,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Muides-sur-Loire',
#   'START_DEST': 85,
#   'END_DEST': 100,
#   'DEST': 'DEST'},
#  {'TEXT': "De Chagny jusqu'à Le Vigan, j'ai suivi les chemins de traverse pour découvrir des panoramas spectaculaires.",
#   'DEPART': 'Chagny',
#   'START_DEPART': 3,
#   'END_DEPART': 8,
#   'DEP': 'DEP',
#   'DESTINATION': 'LeVigan',
#   'START_DEST': 16,
#   'END_DEST': 22,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la route des artisans de Saint-Laurent-du-Var à Haudiomont pour découvrir l'artisanat local et ses secrets.",
#   'DEPART': 'Saint-Laurent-du-Var',
#   'START_DEPART': 30,
#   'END_DEPART': 49,
#   'DEP': 'DEP',
#   'DESTINATION': 'Haudiomont',
#   'START_DEST': 51,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': "De Collan jusqu'à Loucrup, j'ai parcouru des terres fertiles et des déserts arides pour une expérience contrastée.",
#   'DEPART': 'Collan',
#   'START_DEPART': 3,
#   'END_DEPART': 8,
#   'DEP': 'DEP',
#   'DESTINATION': 'Loucrup',
#   'START_DEST': 16,
#   'END_DEST': 22,
#   'DEST': 'DEST'},
#  {'TEXT': "De Issenheim jusqu'à VÃ©rin, chaque étape était une aventure.",
#   'DEPART': 'Issenheim',
#   'START_DEPART': 3,
#   'END_DEPART': 11,
#   'DEP': 'DEP',
#   'DESTINATION': 'VÃ©rin',
#   'START_DEST': 19,
#   'END_DEST': 24,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de PanissiÃ¨res à Bessey-lÃ¨s-CÃ®teaux m'a offert une diversité incroyable.",
#   'DEPART': 'PanissiÃ¨res',
#   'START_DEPART': 12,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bessey-lÃ¨s-CÃ®teaux',
#   'START_DEST': 25,
#   'END_DEST': 44,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai exploré Gircourt-lÃ¨s-ViÃ©ville avant de me diriger vers Saint-Hilaire-la-Gravelle.",
#   'DEPART': 'Gircourt-lÃ¨s-ViÃ©ville',
#   'START_DEPART': 12,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Hilaire-la-Gravelle',
#   'START_DEST': 55,
#   'END_DEST': 79,
#   'DEST': 'DEST'},
#  {'TEXT': "De Sailly-sur-la-Lys jusqu'à Buoux, j'ai exploré les contrastes entre les villes animées et les villages pittoresques.",
#   'DEPART': 'Sailly-sur-la-Lys',
#   'START_DEPART': 3,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Buoux',
#   'START_DEST': 27,
#   'END_DEST': 31,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Castelnau-Tursan, j'ai été émerveillé(e) par la diversité des expériences que cette région offre avant de poursuivre vers Sologny.",
#   'DEPART': 'Castelnau-Tursan',
#   'START_DEPART': 13,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sologny',
#   'START_DEST': 118,
#   'END_DEST': 124,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Arques, j'ai entrepris de découvrir Montbard.",
#   'DEPART': 'Arques',
#   'START_DEPART': 18,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montbard',
#   'START_DEST': 49,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré les rues animées de Alban, j'ai savouré la tranquillité de Lannes.",
#   'DEPART': 'Alban',
#   'START_DEPART': 34,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'Lannes',
#   'START_DEST': 67,
#   'END_DEST': 72,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté MÃ©honcourt pour m'aventurer à Courtoin.",
#   'DEPART': 'MÃ©honcourt',
#   'START_DEPART': 11,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Courtoin',
#   'START_DEST': 38,
#   'END_DEST': 45,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai découvert une culture fascinante à Gaubertin avant de m'immerger dans celle de Sainte-Maure.",
#   'DEPART': 'Gaubertin',
#   'START_DEPART': 35,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-Maure',
#   'START_DEST': 72,
#   'END_DEST': 83,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir arpenté les ruelles étroites de Chasselay, j'ai pris la direction de Agnetz pour une vue panoramique.",
#   'DEPART': 'Chasselay',
#   'START_DEPART': 38,
#   'END_DEPART': 46,
#   'DEP': 'DEP',
#   'DESTINATION': 'Agnetz',
#   'START_DEST': 69,
#   'END_DEST': 74,
#   'DEST': 'DEST'},
#  {'TEXT': "Ma route m'a conduit(e) de Luceau à Taponnat-Fleurignac.",
#   'DEPART': 'Luceau',
#   'START_DEPART': 23,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Taponnat-Fleurignac',
#   'START_DEST': 30,
#   'END_DEST': 48,
#   'DEST': 'DEST'},
#  {'TEXT': 'Lors de votre séjour de Sceau-Saint-Angel à Saint-Lary, vous avez vu beaucoup de choses.',
#   'DEPART': 'Sceau-Saint-Angel',
#   'START_DEPART': 20,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Lary',
#   'START_DEST': 38,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir arpenté les ruelles de Luscan et exploré ses secrets, j'ai pris la direction de Vieux-Moulin pour une atmosphère différente.",
#   'DEPART': 'Luscan',
#   'START_DEPART': 30,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vieux-Moulin',
#   'START_DEST': 77,
#   'END_DEST': 88,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai été inspiré(e) par l'authenticité de Labessette avant de continuer mon voyage vers Auvers-le-Hamon pour une aventure hors du commun.",
#   'DEPART': 'Labessette',
#   'START_DEPART': 37,
#   'END_DEPART': 46,
#   'DEP': 'DEP',
#   'DESTINATION': 'Auvers-le-Hamon',
#   'START_DEST': 76,
#   'END_DEST': 90,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai commencé mon périple à Forges-les-Bains où j'ai été charmé(e) par l'authenticité avant de rejoindre Saint-Lubin-en-Vergonnois pour une expérience inoubliable.",
#   'DEPART': 'Forges-les-Bains',
#   'START_DEPART': 24,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Lubin-en-Vergonnois',
#   'START_DEST': 91,
#   'END_DEST': 115,
#   'DEST': 'DEST'},
#  {'TEXT': "À la suite de ma visite à Villers-le-Sec, j'ai décidé de me rendre à Fonsomme.",
#   'DEPART': 'Villers-le-Sec',
#   'START_DEPART': 20,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Fonsomme',
#   'START_DEST': 56,
#   'END_DEST': 63,
#   'DEST': 'DEST'},
#  {'TEXT': "De Berviller-en-Moselle à Saulgond, j'ai été fasciné(e) par la diversité des paysages.",
#   'DEPART': 'Berviller-en-Moselle',
#   'START_DEPART': 3,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saulgond',
#   'START_DEST': 24,
#   'END_DEST': 31,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire une halte à Baye pour une expérience culturelle unique avant de rejoindre Gouhenans pour la suite de mon voyage.",
#   'DEPART': 'Baye',
#   'START_DEPART': 27,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Gouhenans',
#   'START_DEST': 80,
#   'END_DEST': 88,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Montreuil-sur-Maine, j'ai été ébloui(e) par la diversité architecturale avant de me rendre à LÃ©zignÃ© pour explorer les traditions locales.",
#   'DEPART': 'Montreuil-sur-Maine',
#   'START_DEPART': 13,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'LÃ©zignÃ©',
#   'START_DEST': 93,
#   'END_DEST': 101,
#   'DEST': 'DEST'},
#  {'TEXT': 'En passant de NiÃ©vroz à Loupia, vous avez eu une aventure incroyable.',
#   'DEPART': 'NiÃ©vroz',
#   'START_DEPART': 12,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Loupia',
#   'START_DEST': 21,
#   'END_DEST': 26,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après mon passage à Estadens, je suis parti(e) pour ChÃ¢telraould-Saint-Louvent.',
#   'DEPART': 'Estadens',
#   'START_DEPART': 17,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'ChÃ¢telraould-Saint-Louvent',
#   'START_DEST': 44,
#   'END_DEST': 70,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Ã\x89pense, j'ai fait une halte à Saint-Caprais pour m'imprégner de son histoire avant de poursuivre vers Mondrepuis.",
#   'DEPART': 'Ã\x89pense',
#   'START_DEPART': 18,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Caprais',
#   'START_DEST': 43,
#   'END_DEST': 55,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après Caours est venu Moissannes lors de mon périple.',
#   'DEPART': 'Caours',
#   'START_DEPART': 6,
#   'END_DEPART': 11,
#   'DEP': 'DEP',
#   'DESTINATION': 'Moissannes',
#   'START_DEST': 19,
#   'END_DEST': 28,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Batz-sur-Mer, je me suis dirigé(e) vers CÃ©rans-Foulletourte pour de nouvelles découvertes.',
#   'DEPART': 'Batz-sur-Mer',
#   'START_DEPART': 11,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'CÃ©rans-Foulletourte',
#   'START_DEST': 45,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir contemplé les paysages envoûtants de Hauterive, j'ai pris la route vers Mane.",
#   'DEPART': 'Hauterive',
#   'START_DEPART': 43,
#   'END_DEPART': 51,
#   'DEP': 'DEP',
#   'DESTINATION': 'Mane',
#   'START_DEST': 72,
#   'END_DEST': 75,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Sotteville-sous-le-Val pour aller à Faux-VÃ©signeul, j'ai vécu des aventures incroyables.",
#   'DEPART': 'Sotteville-sous-le-Val',
#   'START_DEPART': 12,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Faux-VÃ©signeul',
#   'START_DEST': 44,
#   'END_DEST': 58,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la piste des aventuriers de Jatxou à Offoy en explorant des sentiers hors des sentiers battus.",
#   'DEPART': 'Jatxou',
#   'START_DEPART': 33,
#   'END_DEPART': 38,
#   'DEP': 'DEP',
#   'DESTINATION': 'Offoy',
#   'START_DEST': 40,
#   'END_DEST': 44,
#   'DEST': 'DEST'},
#  {'TEXT': "De Sessenheim, j'ai fait un saut à Vinassan pour une expérience enrichissante avant de revenir à mon itinéraire initial vers Royville.",
#   'DEPART': 'Sessenheim',
#   'START_DEPART': 3,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Vinassan',
#   'START_DEST': 29,
#   'END_DEST': 36,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Geispitzen, j'ai exploré les quartiers artistiques avant de me rendre à Malouy pour une immersion spirituelle.",
#   'DEPART': 'Geispitzen',
#   'START_DEPART': 13,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Malouy',
#   'START_DEST': 74,
#   'END_DEST': 79,
#   'DEST': 'DEST'},
#  {'TEXT': "Entre Joncels et FÃ¨rebrianges, j'ai rencontré des personnes formidables.",
#   'DEPART': 'Joncels',
#   'START_DEPART': 6,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'FÃ¨rebrianges',
#   'START_DEST': 15,
#   'END_DEST': 27,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Belrupt, j'ai traversé des vallées verdoyantes pour arriver à Le Pertuis et ses montagnes escarpées.",
#   'DEPART': 'Belrupt',
#   'START_DEPART': 12,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'LePertuis',
#   'START_DEST': 65,
#   'END_DEST': 73,
#   'DEST': 'DEST'},
#  {'TEXT': "De Colombier-le-Cardinal à La RÃ©union, j'ai fait une escale enrichissante.",
#   'DEPART': 'Colombier-le-Cardinal',
#   'START_DEPART': 3,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'LaRÃ©union',
#   'START_DEST': 25,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Savigny-lÃ¨s-Beaune, j'ai choisi de m'évader à Cambayrac pour un changement radical d'atmosphère.",
#   'DEPART': 'Savigny-lÃ¨s-Beaune',
#   'START_DEPART': 18,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cambayrac',
#   'START_DEST': 59,
#   'END_DEST': 67,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité RÃ©court, j'ai poursuivi mon périple jusqu'à Chailly-en-BiÃ¨re.",
#   'DEPART': 'RÃ©court',
#   'START_DEPART': 17,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chailly-en-BiÃ¨re',
#   'START_DEST': 56,
#   'END_DEST': 72,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré les rues animées de Euffigneix, je me suis dirigé(e) vers Saint-Julien-la-VÃªtre pour un peu de tranquillité.',
#   'DEPART': 'Euffigneix',
#   'START_DEPART': 34,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Julien-la-VÃªtre',
#   'START_DEST': 66,
#   'END_DEST': 87,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi de passer par Scrupt avant d'explorer Ã\x89trochey.",
#   'DEPART': 'Scrupt',
#   'START_DEPART': 22,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ã\x89trochey',
#   'START_DEST': 43,
#   'END_DEST': 51,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai entrepris mon voyage de Soncourt-sur-Marne à Arreux.",
#   'DEPART': 'Soncourt-sur-Marne',
#   'START_DEPART': 25,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Arreux',
#   'START_DEST': 44,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai visité Coulonvillers avant de découvrir La SÃ©guiniÃ¨re.",
#   'DEPART': 'Coulonvillers',
#   'START_DEPART': 11,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'LaSÃ©guiniÃ¨re',
#   'START_DEST': 40,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir découvert Neulles, j'ai décidé de me rendre à Bernaville pour en voir plus.",
#   'DEPART': 'Neulles',
#   'START_DEPART': 20,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bernaville',
#   'START_DEST': 49,
#   'END_DEST': 58,
#   'DEST': 'DEST'},
#  {'TEXT': "En découvrant Serres-Castet, j'ai été attiré(e) par Madic.",
#   'DEPART': 'Serres-Castet',
#   'START_DEPART': 13,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Madic',
#   'START_DEST': 46,
#   'END_DEST': 50,
#   'DEST': 'DEST'},
#  {'TEXT': 'En passant de Villeloup à HerbÃ©court, tu as découvert de nouvelles perspectives.',
#   'DEPART': 'Villeloup',
#   'START_DEPART': 12,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'HerbÃ©court',
#   'START_DEST': 22,
#   'END_DEST': 32,
#   'DEST': 'DEST'},
#  {'TEXT': "Ma route m'a conduit(e) de Villemandeur à Meursac.",
#   'DEPART': 'Villemandeur',
#   'START_DEPART': 23,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Meursac',
#   'START_DEST': 36,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Villers-Allerand à LiÃ©hon pour vos vacances.',
#   'DEPART': 'Villers-Allerand',
#   'START_DEPART': 18,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'LiÃ©hon',
#   'START_DEST': 35,
#   'END_DEST': 41,
#   'DEST': 'DEST'},
#  {'TEXT': "De Villegly à Sergenon, j'ai fait une escale enrichissante.",
#   'DEPART': 'Villegly',
#   'START_DEPART': 3,
#   'END_DEPART': 10,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sergenon',
#   'START_DEST': 12,
#   'END_DEST': 19,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon itinéraire m'a conduit de Saint-Germain-du-Puch à Plourac'h pour une expérience unique.",
#   'DEPART': 'Saint-Germain-du-Puch',
#   'START_DEPART': 26,
#   'END_DEPART': 46,
#   'DEP': 'DEP',
#   'DESTINATION': "Plourac'h",
#   'START_DEST': 48,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après Charly-sur-Marne est venu Hoffen lors de mon périple.',
#   'DEPART': 'Charly-sur-Marne',
#   'START_DEPART': 6,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Hoffen',
#   'START_DEST': 29,
#   'END_DEST': 34,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Lyon à Puiseux-Pontoise pour un changement de paysage.',
#   'DEPART': 'Lyon',
#   'START_DEPART': 18,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Puiseux-Pontoise',
#   'START_DEST': 23,
#   'END_DEST': 38,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Jort, j'ai été attiré(e) par Cour-Saint-Maurice pour sa riche histoire.",
#   'DEPART': 'Jort',
#   'START_DEPART': 18,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cour-Saint-Maurice',
#   'START_DEST': 42,
#   'END_DEST': 59,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Saint-Michel-Escalus, j'ai poursuivi mon périple jusqu'à Saint-Avit.",
#   'DEPART': 'Saint-Michel-Escalus',
#   'START_DEPART': 17,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Avit',
#   'START_DEST': 68,
#   'END_DEST': 77,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Villemur, j'ai été subjugué(e) par l'authenticité avant de poursuivre vers Burg pour un nouveau chapitre de mon voyage.",
#   'DEPART': 'Villemur',
#   'START_DEPART': 13,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Burg',
#   'START_DEST': 78,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "De Saint-Quay-Perros à Dirol, j'ai suivi les traces des explorateurs anciens tout en explorant des attractions modernes.",
#   'DEPART': 'Saint-Quay-Perros',
#   'START_DEPART': 3,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Dirol',
#   'START_DEST': 21,
#   'END_DEST': 25,
#   'DEST': 'DEST'},
#  {'TEXT': 'Après avoir exploré CÃ©bazat, je suis parti(e) à Creney-prÃ¨s-Troyes.',
#   'DEPART': 'CÃ©bazat',
#   'START_DEPART': 18,
#   'END_DEPART': 25,
#   'DEP': 'DEP',
#   'DESTINATION': 'Creney-prÃ¨s-Troyes',
#   'START_DEST': 42,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': 'Mon voyage de Saint-Gervais-sur-Roubion à Bairon et ses environs était incroyable.',
#   'DEPART': 'Saint-Gervais-sur-Roubion',
#   'START_DEPART': 12,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': 'Baironetsesenvirons',
#   'START_DEST': 38,
#   'END_DEST': 56,
#   'DEST': 'DEST'},
#  {'TEXT': 'Je suis allé(e) de Cayeux-en-Santerre à ThÃ©lis-la-Combe.',
#   'DEPART': 'Cayeux-en-Santerre',
#   'START_DEPART': 16,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'ThÃ©lis-la-Combe',
#   'START_DEST': 35,
#   'END_DEST': 50,
#   'DEST': 'DEST'},
#  {'TEXT': "Lors de mon voyage, de Les Barthes à FrÃ©monville, j'ai découvert de nouveaux horizons qui ont élargi ma perception du monde.",
#   'DEPART': 'LesBarthes',
#   'START_DEPART': 19,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'FrÃ©monville',
#   'START_DEST': 30,
#   'END_DEST': 41,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Fontenay-le-Marmion, j'ai poursuivi mon périple jusqu'à Ville-sur-Saulx.",
#   'DEPART': 'Fontenay-le-Marmion',
#   'START_DEPART': 17,
#   'END_DEPART': 35,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ville-sur-Saulx',
#   'START_DEST': 67,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': 'Elles sont parties de ChÃ¢teauneuf-Villevieille à Forges-sur-Meuse pour une escapade.',
#   'DEPART': 'ChÃ¢teauneuf-Villevieille',
#   'START_DEPART': 19,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Forges-sur-Meuse',
#   'START_DEST': 45,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir profité de la convivialité de Doux, j'ai repris ma route vers Ã\x89roudeville pour découvrir de nouvelles perspectives.",
#   'DEPART': 'Doux',
#   'START_DEPART': 36,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ã\x89roudeville',
#   'START_DEST': 62,
#   'END_DEST': 73,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire un détour par Saint-Saturnin pour apprécier les délices culinaires avant de continuer vers Saint-Victor-sur-Ouche.",
#   'DEPART': 'Saint-Saturnin',
#   'START_DEPART': 29,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Victor-sur-Ouche',
#   'START_DEST': 96,
#   'END_DEST': 117,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Bouquetot à Castetbon m'a permis de constater la diversité incroyable des paysages rencontrés en chemin.",
#   'DEPART': 'Bouquetot',
#   'START_DEPART': 12,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Castetbon',
#   'START_DEST': 22,
#   'END_DEST': 30,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir contemplé Montigny-lÃ¨s-Cormeilles, j'ai entrepris de visiter Ã\x8ele-de-BrÃ©hat.",
#   'DEPART': 'Montigny-lÃ¨s-Cormeilles',
#   'START_DEPART': 20,
#   'END_DEPART': 43,
#   'DEP': 'DEP',
#   'DESTINATION': 'Ã\x8ele-de-BrÃ©hat',
#   'START_DEST': 67,
#   'END_DEST': 81,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai voyagé de La Roche-sur-Foron à Juvincourt-et-Damary pour découvrir de nouvelles coutumes et traditions fascinantes.",
#   'DEPART': 'LaRoche-sur-Foron',
#   'START_DEPART': 13,
# ...
#   'START_DEST': 34,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "Entre Fontcouverte-la-Toussuire et Artagnan, j'ai découvert des endroits merveilleux.",
#   'DEPART': 'Fontcouverte-la-Toussuire',
#   'START_DEPART': 6,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'Artagnan',
#   'START_DEST': 33,
#   'END_DEST': 40,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai continué mon voyage de Villers-Bocage à Le Pouliguen où j'ai été impressionné(e) par la modernité et l'effervescence de la ville.",
#   'DEPART': 'Villers-Bocage',
#   'START_DEPART': 24,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'LePouliguen',
#   'START_DEST': 39,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': 'Je suis allé(e) de La Motte-Saint-Jean à QuiÃ©ry-la-Motte.',
#   'DEPART': 'LaMotte-Saint-Jean',
#   'START_DEPART': 16,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'QuiÃ©ry-la-Motte',
#   'START_DEST': 35,
#   'END_DEST': 50,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant La Croix-en-Touraine, je me suis dirigé(e) vers Bachivillers.',
#   'DEPART': 'LaCroix-en-Touraine',
#   'START_DEPART': 11,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bachivillers',
#   'START_DEST': 52,
#   'END_DEST': 63,
#   'DEST': 'DEST'},
#  {'TEXT': "Lors de mon voyage, de Cuvat à Poigny-la-ForÃªt, j'ai découvert de nouveaux horizons qui ont élargi ma perception du monde.",
#   'DEPART': 'Cuvat',
#   'START_DEPART': 19,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Poigny-la-ForÃªt',
#   'START_DEST': 25,
#   'END_DEST': 40,
#   'DEST': 'DEST'},
#  {'TEXT': "Entre BrÃ©e et Liebenswiller, j'ai découvert une richesse culturelle incroyable.",
#   'DEPART': 'BrÃ©e',
#   'START_DEPART': 6,
#   'END_DEPART': 10,
#   'DEP': 'DEP',
#   'DESTINATION': 'Liebenswiller',
#   'START_DEST': 13,
#   'END_DEST': 25,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Anneux à Parentignat pour un changement de paysage.',
#   'DEPART': 'Anneux',
#   'START_DEPART': 18,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'Parentignat',
#   'START_DEST': 25,
#   'END_DEST': 35,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai exploré Autigny avant de me rendre à Farino.",
#   'DEPART': 'Autigny',
#   'START_DEPART': 12,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Farino',
#   'START_DEST': 35,
#   'END_DEST': 40,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai choisi Marchezais comme prochaine destination après être passé(e) par Batilly-en-Puisaye.",
#   'DEPART': 'Marchezais',
#   'START_DEPART': 11,
#   'END_DEPART': 20,
#   'DEP': 'DEP',
#   'DESTINATION': 'Batilly-en-Puisaye',
#   'START_DEST': 66,
#   'END_DEST': 83,
#   'DEST': 'DEST'},
#  {'TEXT': 'En quittant Labarthe, je me suis dirigé(e) vers Chouday.',
#   'DEPART': 'Labarthe',
#   'START_DEPART': 11,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chouday',
#   'START_DEST': 41,
#   'END_DEST': 47,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple m'a mené de Talmont-Saint-Hilaire à Dracy-le-Fort.",
#   'DEPART': 'Talmont-Saint-Hilaire',
#   'START_DEPART': 20,
#   'END_DEPART': 40,
#   'DEP': 'DEP',
#   'DESTINATION': 'Dracy-le-Fort',
#   'START_DEST': 42,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir passé du temps à Mareuil-sur-Cher, j'ai décidé de visiter Chassagne-Saint-Denis.",
#   'DEPART': 'Mareuil-sur-Cher',
#   'START_DEPART': 24,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'Chassagne-Saint-Denis',
#   'START_DEST': 60,
#   'END_DEST': 80,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré BouxiÃ¨res-aux-ChÃªnes, j'ai fait une halte à Saint-Georges-de-Montclard pour m'imprégner de son histoire avant de poursuivre vers Louvie-Juzon.",
#   'DEPART': 'BouxiÃ¨res-aux-ChÃªnes',
#   'START_DEPART': 18,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Georges-de-Montclard',
#   'START_DEST': 58,
#   'END_DEST': 83,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Teilhet, j'ai ressenti le besoin de me rendre à MissÃ¨cle pour une retraite paisible en pleine nature.",
#   'DEPART': 'Teilhet',
#   'START_DEPART': 17,
#   'END_DEPART': 23,
#   'DEP': 'DEP',
#   'DESTINATION': 'MissÃ¨cle',
#   'START_DEST': 56,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir contemplé Margny-lÃ¨s-CompiÃ¨gne, j'ai décidé de visiter Limerzel.",
#   'DEPART': 'Margny-lÃ¨s-CompiÃ¨gne',
#   'START_DEPART': 20,
#   'END_DEPART': 41,
#   'DEP': 'DEP',
#   'DESTINATION': 'Limerzel',
#   'START_DEST': 62,
#   'END_DEST': 69,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Crochte, je me suis rendu(e) à Saint-Pierre-Roche pour de nouvelles aventures.',
#   'DEPART': 'Crochte',
#   'START_DEPART': 12,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Pierre-Roche',
#   'START_DEST': 37,
#   'END_DEST': 54,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai découvert une culture fascinante à Jaleyrac avant de m'immerger dans celle de Saint-Jean-le-Vieux.",
#   'DEPART': 'Jaleyrac',
#   'START_DEPART': 35,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Jean-le-Vieux',
#   'START_DEST': 71,
#   'END_DEST': 89,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai suivi la trace des explorateurs maritimes de Pont-Ã\xa0-Mousson à SÃ©vignacq-Meyracq pour une aventure océanique.",
#   'DEPART': 'Pont-Ã\xa0-Mousson',
#   'START_DEPART': 43,
#   'END_DEPART': 57,
#   'DEP': 'DEP',
#   'DESTINATION': 'SÃ©vignacq-Meyracq',
#   'START_DEST': 59,
#   'END_DEST': 76,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai découvert Montgiscard après être passé(e) par Roville-devant-Bayon.",
#   'DEPART': 'Montgiscard',
#   'START_DEPART': 14,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Roville-devant-Bayon',
#   'START_DEST': 45,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "De Les Bordes-sur-Arize jusqu'à Baigts-de-BÃ©arn, j'ai suivi les chemins de traverse pour découvrir des panoramas spectaculaires.",
#   'DEPART': 'LesBordes-sur-Arize',
#   'START_DEPART': 3,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Baigts-de-BÃ©arn',
#   'START_DEST': 29,
#   'END_DEST': 44,
#   'DEST': 'DEST'},
#  {'TEXT': 'Parti(e) de Pern et arrivé(e) à Dolus-le-Sec, un voyage parsemé de découvertes culturelles et humaines.',
#   'DEPART': 'Pern',
#   'START_DEPART': 11,
#   'END_DEPART': 14,
#   'DEP': 'DEP',
#   'DESTINATION': 'Dolus-le-Sec',
#   'START_DEST': 27,
#   'END_DEST': 38,
#   'DEST': 'DEST'},
#  {'TEXT': "De Montain jusqu'à Wisembach, j'ai suivi le cours d'un fleuve et découvert des paysages à couper le souffle.",
#   'DEPART': 'Montain',
#   'START_DEPART': 3,
#   'END_DEPART': 9,
#   'DEP': 'DEP',
#   'DESTINATION': 'Wisembach',
#   'START_DEST': 17,
#   'END_DEST': 25,
#   'DEST': 'DEST'},
#  {'TEXT': "De Boutencourt jusqu'à Labeuville, j'ai suivi le cours d'un fleuve et découvert des paysages à couper le souffle.",
#   'DEPART': 'Boutencourt',
#   'START_DEPART': 3,
#   'END_DEPART': 13,
#   'DEP': 'DEP',
#   'DESTINATION': 'Labeuville',
#   'START_DEST': 21,
#   'END_DEST': 30,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai quitté ma ville natale de Saint-Laurent-du-Mont pour me plonger dans l'effervescence de Mont-le-Vignoble et sa vie nocturne animée.",
#   'DEPART': 'Saint-Laurent-du-Mont',
#   'START_DEPART': 26,
#   'END_DEPART': 46,
#   'DEP': 'DEP',
#   'DESTINATION': 'Mont-le-Vignoble',
#   'START_DEST': 81,
#   'END_DEST': 96,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai exploré Valencin avant de me diriger vers Saint-Germain-la-Campagne.",
#   'DEPART': 'Valencin',
#   'START_DEPART': 12,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Germain-la-Campagne',
#   'START_DEST': 40,
#   'END_DEST': 64,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai continué mon voyage de La Rochette à Saint-Remy-sous-Barbuise.",
#   'DEPART': 'LaRochette',
#   'START_DEPART': 24,
#   'END_DEPART': 33,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Remy-sous-Barbuise',
#   'START_DEST': 35,
#   'END_DEST': 58,
#   'DEST': 'DEST'},
#  {'TEXT': "À la suite de ma visite à HÃ©nencourt, j'ai décidé de me rendre à Les Gours.",
#   'DEPART': 'HÃ©nencourt',
#   'START_DEPART': 20,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'LesGours',
#   'START_DEST': 53,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': "TrÃ©gomeur m'a enchanté(e) avant d'atteindre Sadroc.",
#   'DEPART': 'TrÃ©gomeur',
#   'START_DEPART': 1,
#   'END_DEPART': 10,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sadroc',
#   'START_DEST': 41,
#   'END_DEST': 46,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré les rues animées de Yutz, j'ai savouré la tranquillité de Montaud.",
#   'DEPART': 'Yutz',
#   'START_DEPART': 34,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Montaud',
#   'START_DEST': 66,
#   'END_DEST': 72,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Ã\x89taves-et-Bocquiaux pour aller à Thuy, j'ai vécu des aventures incroyables.",
#   'DEPART': 'Ã\x89taves-et-Bocquiaux',
#   'START_DEPART': 12,
#   'END_DEPART': 31,
#   'DEP': 'DEP',
#   'DESTINATION': 'Thuy',
#   'START_DEST': 42,
#   'END_DEST': 45,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir visité Quincy, j'ai poursuivi mon voyage jusqu'à Courmelles.",
#   'DEPART': 'Quincy',
#   'START_DEPART': 17,
#   'END_DEPART': 22,
#   'DEP': 'DEP',
#   'DESTINATION': 'Courmelles',
#   'START_DEST': 53,
#   'END_DEST': 62,
#   'DEST': 'DEST'},
#  {'TEXT': "De Saint-Gobert à Les AveniÃ¨res Veyrins-Thuellin, chaque étape était une aventure unique où j'ai rencontré des gens formidables et découvert des traditions fascinantes.",
#   'DEPART': 'Saint-Gobert',
#   'START_DEPART': 3,
#   'END_DEPART': 14,
#   'DEP': 'DEP',
#   'DESTINATION': 'LesAveniÃ¨resVeyrins-Thuellin',
#   'START_DEST': 16,
#   'END_DEST': 44,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Palluel, j'ai décidé de découvrir Avernes.",
#   'DEPART': 'Palluel',
#   'START_DEPART': 18,
#   'END_DEPART': 24,
#   'DEP': 'DEP',
#   'DESTINATION': 'Avernes',
#   'START_DEST': 47,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "De Fontaine-lÃ¨s-Croisilles à Bassy, j'ai vécu des moments inoubliables.",
#   'DEPART': 'Fontaine-lÃ¨s-Croisilles',
#   'START_DEPART': 3,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bassy',
#   'START_DEST': 28,
#   'END_DEST': 32,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon voyage de Guilherand-Granges à Villevieille m'a offert une diversité incroyable.",
#   'DEPART': 'Guilherand-Granges',
#   'START_DEPART': 12,
#   'END_DEPART': 29,
#   'DEP': 'DEP',
#   'DESTINATION': 'Villevieille',
#   'START_DEST': 31,
#   'END_DEST': 42,
#   'DEST': 'DEST'},
#  {'TEXT': "En passant par Lachambre, j'ai été ébloui(e) par la diversité architecturale avant de me rendre à Aillon-le-Jeune pour explorer les traditions locales.",
#   'DEPART': 'Lachambre',
#   'START_DEPART': 13,
#   'END_DEPART': 21,
#   'DEP': 'DEP',
#   'DESTINATION': 'Aillon-le-Jeune',
#   'START_DEST': 83,
#   'END_DEST': 97,
#   'DEST': 'DEST'},
#  {'TEXT': "En voyageant de La Petite-Pierre à Longcochon, j'ai été surpris(e) par la richesse culturelle.",
#   'DEPART': 'LaPetite-Pierre',
#   'START_DEPART': 14,
#   'END_DEPART': 28,
#   'DEP': 'DEP',
#   'DESTINATION': 'Longcochon',
#   'START_DEST': 30,
#   'END_DEST': 39,
#   'DEST': 'DEST'},
#  {'TEXT': "En partant de Scey-sur-SaÃ´ne-et-Saint-Albin, j'ai été attiré(e) par la vie nocturne effervescente de Savenay.",
#   'DEPART': 'Scey-sur-SaÃ´ne-et-Saint-Albin',
#   'START_DEPART': 12,
#   'END_DEPART': 41,
#   'DEP': 'DEP',
#   'DESTINATION': 'Savenay',
#   'START_DEST': 90,
#   'END_DEST': 96,
#   'DEST': 'DEST'},
#  {'TEXT': "Après mon séjour à La Genevroye, j'ai continué vers Trinay.",
#   'DEPART': 'LaGenevroye',
#   'START_DEPART': 16,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Trinay',
#   'START_DEST': 44,
#   'END_DEST': 49,
#   'DEST': 'DEST'},
#  {'TEXT': "De Picherande à Melun, j'ai été captivé(e) par la beauté des lieux.",
#   'DEPART': 'Picherande',
#   'START_DEPART': 3,
#   'END_DEPART': 12,
#   'DEP': 'DEP',
#   'DESTINATION': 'Melun',
#   'START_DEST': 14,
#   'END_DEST': 18,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai décidé de faire une halte à BetbÃ¨ze pour une expérience culturelle unique avant de rejoindre Dessenheim pour la suite de mon voyage.",
#   'DEPART': 'BetbÃ¨ze',
#   'START_DEPART': 27,
#   'END_DEPART': 34,
#   'DEP': 'DEP',
#   'DESTINATION': 'Dessenheim',
#   'START_DEST': 84,
#   'END_DEST': 93,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir exploré Incarville, j'ai décidé de découvrir Sap-en-Auge.",
#   'DEPART': 'Incarville',
#   'START_DEPART': 18,
#   'END_DEPART': 27,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sap-en-Auge',
#   'START_DEST': 50,
#   'END_DEST': 60,
#   'DEST': 'DEST'},
#  {'TEXT': "Après mon séjour à Cardonville, j'ai continué vers Beaumont-le-Hareng.",
#   'DEPART': 'Cardonville',
#   'START_DEPART': 16,
#   'END_DEPART': 26,
#   'DEP': 'DEP',
#   'DESTINATION': 'Beaumont-le-Hareng',
#   'START_DEST': 44,
#   'END_DEST': 61,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Le Faou, je me suis rendu(e) à Cuiserey pour de nouvelles aventures.',
#   'DEPART': 'LeFaou',
#   'START_DEPART': 12,
#   'END_DEPART': 17,
#   'DEP': 'DEP',
#   'DESTINATION': 'Cuiserey',
#   'START_DEST': 36,
#   'END_DEST': 43,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon itinéraire m'a conduit de Tilloy-Floriville à Conteville pour une expérience unique.",
#   'DEPART': 'Tilloy-Floriville',
#   'START_DEPART': 26,
#   'END_DEPART': 42,
#   'DEP': 'DEP',
#   'DESTINATION': 'Conteville',
#   'START_DEST': 44,
#   'END_DEST': 53,
#   'DEST': 'DEST'},
#  {'TEXT': "Mon périple m'a conduit(e) de Vaudrecourt à Saint-ChÃ©ly-d'Aubrac où j'ai eu l'occasion de m'immerger dans l'histoire fascinante de ces lieux.",
#   'DEPART': 'Vaudrecourt',
#   'START_DEPART': 26,
#   'END_DEPART': 36,
#   'DEP': 'DEP',
#   'DESTINATION': "Saint-ChÃ©ly-d'Aubrac",
#   'START_DEST': 38,
#   'END_DEST': 58,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir arpenté les ruelles de Hennezel et exploré ses secrets, j'ai pris la direction de Saint-Laurent-sur-Oust pour une atmosphère différente.",
#   'DEPART': 'Hennezel',
#   'START_DEPART': 30,
#   'END_DEPART': 37,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Laurent-sur-Oust',
#   'START_DEST': 79,
#   'END_DEST': 100,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir apprécié la gastronomie de Saint-Germain-des-FossÃ©s, j'ai repris ma route vers Saint-Ouen-la-ThÃ¨ne pour une exploration plus approfondie.",
#   'DEPART': 'Saint-Germain-des-FossÃ©s',
#   'START_DEPART': 34,
#   'END_DEPART': 58,
#   'DEP': 'DEP',
#   'DESTINATION': 'Saint-Ouen-la-ThÃ¨ne',
#   'START_DEST': 81,
#   'END_DEST': 100,
#   'DEST': 'DEST'},
#  {'TEXT': "De Noyers-sur-Cher à Quesques, j'ai suivi les traces des explorateurs anciens tout en explorant des attractions modernes.",
#   'DEPART': 'Noyers-sur-Cher',
#   'START_DEPART': 3,
#   'END_DEPART': 17,
#   'DEP': 'DEP',
#   'DESTINATION': 'Quesques',
#   'START_DEST': 19,
#   'END_DEST': 26,
#   'DEST': 'DEST'},
#  {'TEXT': "En quittant CoÃ«smes, j'ai été captivé(e) par la diversité culturelle de DamrÃ©mont.",
#   'DEPART': 'CoÃ«smes',
#   'START_DEPART': 11,
#   'END_DEPART': 18,
#   'DEP': 'DEP',
#   'DESTINATION': 'DamrÃ©mont',
#   'START_DEST': 63,
#   'END_DEST': 72,
#   'DEST': 'DEST'},
#  {'TEXT': "Après avoir arpenté les ruelles de Dannemoine et exploré ses secrets, j'ai pris la direction de Lachassagne pour une atmosphère différente.",
#   'DEPART': 'Dannemoine',
#   'START_DEPART': 30,
#   'END_DEPART': 39,
#   'DEP': 'DEP',
#   'DESTINATION': 'Lachassagne',
#   'START_DEST': 81,
#   'END_DEST': 91,
#   'DEST': 'DEST'},
#  {'TEXT': "J'ai continué mon voyage de Castelnau Montratier-Sainte Alauzie à Sainte-SÃ©vÃ¨re-sur-Indre où j'ai été impressionné(e) par la modernité et l'effervescence de la ville.",
#   'DEPART': 'CastelnauMontratier-SainteAlauzie',
#   'START_DEPART': 24,
#   'END_DEPART': 56,
#   'DEP': 'DEP',
#   'DESTINATION': 'Sainte-SÃ©vÃ¨re-sur-Indre',
#   'START_DEST': 58,
#   'END_DEST': 82,
#   'DEST': 'DEST'},
#  {'TEXT': 'En partant de Juvigny-sur-Seulles, je me suis dirigé(e) vers La FermetÃ©.',
#   'DEPART': 'Juvigny-sur-Seulles',
#   'START_DEPART': 12,
#   'END_DEPART': 30,
#   'DEP': 'DEP',
#   'DESTINATION': 'LaFermetÃ©',
#   'START_DEST': 53,
#   'END_DEST': 62,
#   'DEST': 'DEST'},
#  {'TEXT': "En explorant Bommiers, j'ai été ébloui(e) par la richesse architecturale avant de me diriger vers Duras.",
#   'DEPART': 'Bommiers',
#   'START_DEPART': 12,
#   'END_DEPART': 19,
#   'DEP': 'DEP',
#   'DESTINATION': 'Duras',
#   'START_DEST': 84,
#   'END_DEST': 88,
#   'DEST': 'DEST'},
#  {'TEXT': 'Vous êtes allé(e) de Sainte-Blandine à Bretigney pour un changement de paysage.',
#   'DEPART': 'Sainte-Blandine',
#   'START_DEPART': 18,
#   'END_DEPART': 32,
#   'DEP': 'DEP',
#   'DESTINATION': 'Bretigney',
#   'START_DEST': 34,
#   'END_DEST': 42,
#   'DEST': 'DEST'}]
